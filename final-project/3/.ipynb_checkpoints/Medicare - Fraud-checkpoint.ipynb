# %% [markdown]
# # Medicare - Finding Frauds
#
# https://www.cms.gov/Research-Statistics-Data-and-Systems/Downloadable-Public-Use-Files/SynPUFs/DE_Syn_PUF.html
#
# Unfortunately, synthetic use medicare files are only available for 2008-2010... only provider information is available for 2010 + (see other notebook).... This is a set of 5% of random sampling of data from this time frame, and is broken into 20 seconds. To start, just bring in one of the claims samples.
#
# The Basics:
#
# Every claim (visit, drug, procedure, diagnosis) consists of a code, which is pre-negotiated
#
# Example of fraud: "accidentally" adding an extra service
#
# Goal: build a model of "normal" claims, based on things that normally go together (e.g. a cast with an x-ray)
#
# Slightly more technical:
# - consider each claim as a cluster of codes
# - treat the co-occurance of terms in a claim as their similarity
# - we can think of the average distance between the terms as 1 / similarity
# - extrapolating to a cluster, compute the average diameter of the cluster (square root of the sum of squared distances of all codes)
#
# Let's set if it makes sense...

# %%
import itertools
import numpy as np
import os.path
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer

# %matplotlib inline

folder = os.getcwd()

# extract codes as bag of codes from input
outpatient_df = pd.read_csv(os.path.join(folder, "..", "DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv"), low_memory=False)
outpatient_df.head()
# Out:
#         DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0  00013D2EFD8E45D1  542192281063886        1   20080904.0   20080904.0
# 1  00016F745862898F  542272281166593        1   20090602.0   20090602.0
# 2  00016F745862898F  542282281644416        1   20090623.0   20090623.0
# 3  0001FDD721E223DC  542642281250669        1   20091011.0   20091011.0
# 4  00024B3D2352D2D0  542242281386963        1   20080712.0   20080712.0
#
#   PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# 0    2600RA         50.0                       0.0  4.824842e+09
# 1    3901GS         30.0                       0.0  2.963420e+09
# 2    3939PG         30.0                       0.0  5.737808e+09
# 3    3902NU         30.0                       0.0  1.233848e+09
# 4    5200TV         30.0                       0.0  9.688809e+09
#
#    OP_PHYSN_NPI     ...      HCPCS_CD_36  HCPCS_CD_37 HCPCS_CD_38 HCPCS_CD_39  \
# 0           NaN     ...              NaN          NaN         NaN         NaN
# 1           NaN     ...              NaN          NaN         NaN         NaN
# 2           NaN     ...              NaN          NaN         NaN         NaN
# 3           NaN     ...              NaN          NaN         NaN         NaN
# 4           NaN     ...              NaN          NaN         NaN         NaN
#
#   HCPCS_CD_40 HCPCS_CD_41 HCPCS_CD_42 HCPCS_CD_43 HCPCS_CD_44 HCPCS_CD_45
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 76 columns]

# %%
outpatient_df.shape
# Out:
# (790790, 76)

# %%
outpatient_df.columns
# Out:
# Index([u'DESYNPUF_ID', u'CLM_ID', u'SEGMENT', u'CLM_FROM_DT', u'CLM_THRU_DT',
#        u'PRVDR_NUM', u'CLM_PMT_AMT', u'NCH_PRMRY_PYR_CLM_PD_AMT',
#        u'AT_PHYSN_NPI', u'OP_PHYSN_NPI', u'OT_PHYSN_NPI',
#        u'NCH_BENE_BLOOD_DDCTBL_LBLTY_AM', u'ICD9_DGNS_CD_1', u'ICD9_DGNS_CD_2',
#        u'ICD9_DGNS_CD_3', u'ICD9_DGNS_CD_4', u'ICD9_DGNS_CD_5',
#        u'ICD9_DGNS_CD_6', u'ICD9_DGNS_CD_7', u'ICD9_DGNS_CD_8',
#        u'ICD9_DGNS_CD_9', u'ICD9_DGNS_CD_10', u'ICD9_PRCDR_CD_1',
#        u'ICD9_PRCDR_CD_2', u'ICD9_PRCDR_CD_3', u'ICD9_PRCDR_CD_4',
#        u'ICD9_PRCDR_CD_5', u'ICD9_PRCDR_CD_6', u'NCH_BENE_PTB_DDCTBL_AMT',
#        u'NCH_BENE_PTB_COINSRNC_AMT', u'ADMTNG_ICD9_DGNS_CD', u'HCPCS_CD_1',
#        u'HCPCS_CD_2', u'HCPCS_CD_3', u'HCPCS_CD_4', u'HCPCS_CD_5',
#        u'HCPCS_CD_6', u'HCPCS_CD_7', u'HCPCS_CD_8', u'HCPCS_CD_9',
#        u'HCPCS_CD_10', u'HCPCS_CD_11', u'HCPCS_CD_12', u'HCPCS_CD_13',
#        u'HCPCS_CD_14', u'HCPCS_CD_15', u'HCPCS_CD_16', u'HCPCS_CD_17',
#        u'HCPCS_CD_18', u'HCPCS_CD_19', u'HCPCS_CD_20', u'HCPCS_CD_21',
#        u'HCPCS_CD_22', u'HCPCS_CD_23', u'HCPCS_CD_24', u'HCPCS_CD_25',
#        u'HCPCS_CD_26', u'HCPCS_CD_27', u'HCPCS_CD_28', u'HCPCS_CD_29',
#        u'HCPCS_CD_30', u'HCPCS_CD_31', u'HCPCS_CD_32', u'HCPCS_CD_33',
#        u'HCPCS_CD_34', u'HCPCS_CD_35', u'HCPCS_CD_36', u'HCPCS_CD_37',
#        u'HCPCS_CD_38', u'HCPCS_CD_39', u'HCPCS_CD_40', u'HCPCS_CD_41',
#        u'HCPCS_CD_42', u'HCPCS_CD_43', u'HCPCS_CD_44', u'HCPCS_CD_45'],
#       dtype='object')

# %%
# create a series codebag which joins all the codes into a string for a given visit

def join_codes(row):
    return " ".join([str(v) for i, v in row.iteritems() if pd.notnull(v)])

# all the code columns have _CD_ in them

colnames = [colname for colname in outpatient_df.columns if "_CD_" in colname]
codebag = outpatient_df.ix[:, colnames].apply(join_codes, axis=1)
codebag.head()
# Out:
# 0                                    V5841 85610 84153
# 1    V5832 V5861 2724 3182 V5869 42731 85610 80048 ...
# 2                    9594 E9174 4019 71101 78480 94060
# 3                              78943 V5866 V1272 36415
# 4                                     6009 76872 82365
# dtype: object

# %%
codebag.isnull().sum()
# Out:
# 0

# %%
# use the codes to build a sparse matrix
# essentially, convert collection of text documents to a matrix of token counts
vec = CountVectorizer(min_df=1, binary=True)
X = vec.fit_transform(codebag)

X.shape
# Out:
# (790790, 17023)

# %%
# this is the sort of data we will use

# first row
[code for code in X[1, :].nonzero()][1]
# Out:
# array([11823, 16611, 16619,  2667,  3689, 16626,  5497, 10524, 10534,
#        11112, 13625, 12103, 11642, 10543, 11480], dtype=int32)

# %%
# sanity check

import scipy.sparse as sps

sps.issparse(X)
# Out:
# True

# %%
# so, we can compute the similarities by multiplying by the transpose, giving us a 17023 ^ 2 matrix
# the similarity is the number of times the terms co-occur in a claim (document)
# we can use the similarity to compute an average distance

similarity = X.T * X
similarity.shape
# Out:
# (17023, 17023)

# %%
similarity.getrow(1).todense()[:, 1]
# Out:
# matrix([[2]])

# %%
# now, use the similarities to determine the consistency of codes within a claim
# to do this, compute the average diameter of all codes in the claim (square root of sum of squares)

# generates a file with a series of numbers, where each number is the cluster diameter for a single claim
# creates a univariate distribution, so it is easy to find outliers

# THIS IS REALLY SLOW --- like, hours
# run this out of python notebook, since there is a memory leak running it here

# there is probably a much faster way to compute this...

import gc

EPSILON = 0.001

fileout = open(os.path.join(folder, "..", "clusters-proc.txt"), 'wb')

for row in range(0, X.shape[0]):
    # manual garbage collection
    if row % 50 == 0:
        print("row " + str(row))
        gc.collect()
    # get non-zero codes in the row from our CountVectorizer matrix
    codes = [code for code in X[row, :].nonzero()][1]
    dists = []
    for i, j in itertools.product(codes, codes):
        # only take thhe upper triangle
        if i < j:
            sim_ij = similarity.getrow(i).todense()[:, j][0]
            if sim_ij == 0:
                sim_ij = EPSILON
            dists.append(1 / (sim_ij ** 2)) 
    fileout.write("%f\n" % (np.sqrt(sum(dists)) / len(dists)))

fileout.close()
# Out:
# row 0
# /Users/maxwellbates/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:31: RuntimeWarning: invalid value encountered in double_scalars
# row 50
# row 100
# row 150
# row 200
# row 250
# row 300
# row 350
# row 400
# row 450
# row 500
# row 550
# row 600
# row 650
# row 700
# row 750
# row 800
# row 850
# row 900
# row 950
# row 1000
# row 1050
# row 1100
# row 1150
# row 1200
# row 1250
# row 1300
# row 1350
# row 1400
# row 1450
# row 1500
# row 1550
# row 1600
# row 1650
# row 1700
# row 1750
# row 1800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-10671d46b0d0> in <module>()
#      25         # only take thhe upper triangle
#      26         if i < j:
# ---> 27             sim_ij = similarity.getrow(i).todense()[:, j][0]
#      28             if sim_ij == 0:
#      29                 sim_ij = EPSILON
#
# /Users/maxwellbates/anaconda/lib/python2.7/site-packages/scipy/sparse/csc.pyc in getrow(self, i)
#     203         # we convert to CSR to maintain compatibility with old impl.
#     204         # in spmatrix.getrow()
# --> 205         return self._get_submatrix(i, slice(None)).tocsr()
#     206
#     207     def getcol(self, i):
#
# /Users/maxwellbates/anaconda/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in _get_submatrix(self, slice0, slice1)
#     892                                              self.indptr, self.indices,
#     893                                              self.data,
# --> 894                                              i0, i1, j0, j1)
#     895
#     896         data, indices, indptr = aux[2], aux[1], aux[0]
#
# KeyboardInterrupt:

# %%
# load contents into a pandas series

clusters = pd.read_csv(os.path.join(folder, "..", "clusters-45500.txt"), header=None, delim_whitespace=True, names=['distance'], dtype=float)
clusters = clusters['distance']
clusters
# Out:
# 0        0.000000
# 1        0.016496
# 2        0.149071
# 3        0.166667
# 4        0.471405
# 5        0.000000
# 6        0.000000
# 7        0.000000
# 8             NaN
# 9        0.000000
# 10       0.000000
# 11       0.000000
# 12       0.000000
# 13       0.035714
# 14       0.000000
# 15       0.037113
# 16       0.039284
# 17       0.100000
# 18       0.141421
# 19       0.022810
# 20       0.035714
# 21       0.066667
# 22       0.055556
# 23       0.333333
# 24       0.288675
# 25       0.100000
# 26       0.000000
# 27       0.000000
# 28       0.000000
# 29       0.000000
#            ...
# 45504    0.000000
# 45505    0.047619
# 45506    0.094281
# 45507    0.000000
# 45508    0.000000
# 45509    0.000000
# 45510    0.000000
# 45511    0.000000
# 45512    0.000000
# 45513    0.010081
# 45514    0.133333
# 45515    0.029230
# 45516    0.066667
# 45517    0.000000
# 45518    0.000000
# 45519    0.000000
# 45520    0.100000
# 45521    0.000000
# 45522    0.061859
# 45523    0.000000
# 45524    0.000000
# 45525    0.000000
# 45526    0.166667
# 45527    0.086066
# 45528    0.032967
# 45529    0.013692
# 45530    0.035714
# 45531    0.100000
# 45532    0.000000
# 45533    0.000000
# Name: distance, dtype: float64

# %%
# mean and median
clusters.describe()
# Out:
# count    44406.000000
# mean         0.073278
# std          0.167844
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.066667
# max          1.000000
# Name: distance, dtype: float64

# %%
# plot what we got

clusters.plot.hist(bins=100)

# %%
# hoping for a normal distribution, but not so much
# plot log-scaled, which is more normal, but skews

clusters.plot(kind='hist', bins=100, logy=True)

# %%
# plot boxplot to easily see if we have outliers....

import seaborn as sns

sns.boxplot(x=clusters, whis=3)

# %%
# calculate the cumulative sum, and 

cumulative_sums = clusters.cumsum()
total_sum = cumulative_sums.iloc[-1]

# todo - should compute percentage, not of some, but of data distribution
cut_99 = 0.99 * total_sum
cut_95 = 0.95 * total_sum

print "sum", total_sum, "\n99%", cut_99, "\n95%", cut_95
# Out:
# sum 3253.970986
# 99% 3221.43127614
# 95% 3091.2724367

# %%
# there are some codes which only show up once and will of course look like outliers...

# technically, they should equal one
THRESHOLD_SINGLE_CODE= 0.9999

# our threshold for outliers (should be by std deviations - TODO: compute)
THRESHOLD_OUTLIER = 0.35

single_code = clusters.ix[ clusters > THRESHOLD_SINGLE_CODE ]
print(str(len(single_code)) + ' rows have codes that only show up once')
# Out:
# 951 rows have codes that only show up once

# %%
# then, find the rows which are outliers without having a single code

outliers = clusters.ix[ (clusters > THRESHOLD_OUTLIER) & (clusters < THRESHOLD_SINGLE_CODE) ]
outliers.sort_values(ascending=False)
# Out:
# 16460    0.577350
# 26777    0.577350
# 15212    0.577350
# 7903     0.577350
# 7848     0.577350
# 38060    0.577350
# 15746    0.577350
# 7269     0.577350
# 7098     0.577350
# 38944    0.577350
# 38999    0.577350
# 39003    0.577350
# 39088    0.577350
# 16099    0.577350
# 26853    0.577350
# 6711     0.577350
# 39490    0.577350
# 41315    0.577350
# 39600    0.577350
# 39604    0.577350
# 26640    0.577350
# 12890    0.577350
# 39886    0.577350
# 26382    0.577350
# 16543    0.577350
# 40089    0.577350
# 25961    0.577350
# 5870     0.577350
# 40722    0.577350
# 25305    0.577350
#            ...
# 29703    0.471405
# 29400    0.471405
# 29910    0.471405
# 30102    0.471405
# 30339    0.471405
# 30318    0.471405
# 30186    0.471405
# 30154    0.471405
# 30032    0.471405
# 30140    0.471405
# 30082    0.471405
# 43239    0.408248
# 19267    0.408248
# 33472    0.408248
# 37518    0.408248
# 45299    0.408248
# 14235    0.408248
# 20682    0.408248
# 28002    0.408248
# 39867    0.408248
# 10108    0.408248
# 965      0.408248
# 4962     0.408248
# 9262     0.408248
# 26116    0.408248
# 1104     0.408248
# 6652     0.408248
# 39384    0.408248
# 31782    0.408248
# 17832    0.408248
# Name: distance, dtype: float64

# %%
# ok, now lets see what these codes actually are....
# weirdly very hard to find these codes, and ICD9 are different than HCPCS (I couldn't find anything)

# manually import, since not tab delimited
icd9_codes = pd.read_table(os.path.join(folder, "..", "ICD9_codes.txt"), names=['string'], header=None, low_memory=False)

icd9_codes = dict(zip(
    icd9_codes.string.map(lambda string: string.split(' ', 1)[0]),
    icd9_codes.string.map(lambda string: string.split(' ', 1)[1].strip())
    ))

# %%
# lets print what these outliers are

# many will print Unknown Code, since only ICD9 codes were available (not HCPCS), and incomplete list

for idx, score in sorted(outliers.iteritems():
    claim_id = outpatient_df.ix[idx, 'CLM_ID']
    codes = codebag[idx].split( )
    codes_text = ', '.join(codes)
    print("%s \t %5.4f \t %s" % (claim_id, score, codes_text))
    for code in codes:
        if code in icd9_codes:
            print(code + ' - ' + icd9_codes[code])
        else:
            print(code + " - (Unknown)")
    print("\n")
# Out:
# 542242281386963 	 0.4714 	 6009, 76872, 82365
# Unknown Code: 6009
# Moderate hypoxic-ischemic encephalopathy
# Unknown Code: 82365
#
#
# 542712281272543 	 0.5774 	 71658, 81341, 95900
# Unspecified polyarthropathy or polyarthritis, other specified sites
# Closed Colles' fracture
# Unknown Code: 95900
#
#
# 542802281290868 	 0.4714 	 1118, 99201, 88312
# Other specified dermatomycoses
# Unknown Code: 99201
# Unknown Code: 88312
#
#
# 542322281083845 	 0.4714 	 48283, 51889, 87015
# Pneumonia due to other gram-negative bacteria
# Other diseases of lung, not elsewhere classified
# Unknown Code: 87015
#
#
# 542422280935803 	 0.4714 	 47834, 73510, 97110
# Bilateral paralysis of vocal cords or larynx, complete
# Unknown Code: 73510
# Unknown Code: 97110
#
#
# 542902280861458 	 0.4714 	 2182, 6202, 6262
# Subserous leiomyoma of uterus
# Other and unspecified ovarian cyst
# Excessive or frequent menstruation
#
#
# 542512281258380 	 0.4714 	 24240, 8449, 76536
# Thyrotoxicosis from ectopic thyroid nodule without mention of thyrotoxic crisis or storm
# Sprains and strains of unspecified site of knee and leg
# Unknown Code: 76536
#
#
# 542572280966944 	 0.4714 	 6144, 87081, 87186
# Chronic or unspecified parametritis and pelvic cellulitis
# Unknown Code: 87081
# Unknown Code: 87186
#
#
# 542562281602441 	 0.5774 	 2568, 82652, 78891
# Other ovarian dysfunction
# Unknown Code: 82652
# Functional urinary incontinence
#
#
# 542492281573490 	 0.4714 	 38845, V5251, 92567
# Acquired auditory processing disorder
# Unknown Code: V5251
# Unknown Code: 92567
#
#
# 542412281597845 	 0.4082 	 36114, 36254, 99203, 92083
# Secondary retinal cysts
# Macular cyst, hole, or pseudohole
# Unknown Code: 99203
# Unknown Code: 92083
#
#
# 542892281429871 	 0.4714 	 33720, 73510, 95904
# Reflex sympathetic dystrophy, unspecified
# Unknown Code: 73510
# Unknown Code: 95904
#
#
# 542142281467209 	 0.4714 	 72740, 71901, 97002
# Synovial cyst, unspecified
# Effusion of joint, shoulder region
# Unknown Code: 97002
#
#
# 542312281574557 	 0.4714 	 7879, 5690, J7040
# Unknown Code: 7879
# Anal and rectal polyp
# Unknown Code: J7040
#
#
# 542132281400960 	 0.4082 	 73345, 84500, 73200, 82575
# Aseptic necrosis of bone, jaw
# Sprain of ankle, unspecified site
# Unknown Code: 73200
# Unknown Code: 82575
#
#
# 542772281279242 	 0.4714 	 34661, 5712, 34290
# Persistent migraine aura with cerebral infarction, with intractable migraine, so stated, without mention of status migrainosus
# Alcoholic cirrhosis of liver
# Hemiplegia, unspecified, affecting unspecified side
#
#
# 542832281458590 	 0.4714 	 9144, E8499, 99281
# Insect bite, nonvenomous, of hand(s) except finger(s) alone, without mention of infection
# Accidents occurring in unspecified place
# Unknown Code: 99281
#
#
# 542322281239639 	 0.4714 	 8760, E9289, 99213
# Open wound of back, without mention of complication
# Unspecified accident
# Unknown Code: 99213
#
#
# 542692281149377 	 0.5774 	 78600, 1539, 86022
# Respiratory abnormality, unspecified
# Malignant neoplasm of colon, unspecified site
# Unknown Code: 86022
#
#
# 542962281381104 	 0.4714 	 4644, 1120, 2859
# Croup
# Candidiasis of mouth
# Anemia, unspecified
#
#
# 542062281610911 	 0.4714 	 72883, V1254, 96372
# Rupture of muscle, nontraumatic
# Personal history of transient ischemic attack (TIA), and cerebral infarction without residual deficits
# Unknown Code: 96372
#
#
# 542222281210246 	 0.4714 	 7248, 95990, 92526
# Other symptoms referable to back
# Unknown Code: 95990
# Unknown Code: 92526
#
#
# 542392281429408 	 0.4714 	 1821, 1970, 88175
# Malignant neoplasm of isthmus
# Secondary malignant neoplasm of lung
# Unknown Code: 88175
#
#
# 542362281049789 	 0.4714 	 71982, V1588, 72192
# Other specified disorders of joint, upper arm
# History of fall
# Unknown Code: 72192
#
#
# 542342281442602 	 0.5774 	 9392, 71589, 73060
# Foreign body in vulva and vagina
# Osteoarthrosis involving, or with mention of more than one site, but not specified as generalized, multiple sites
# Unknown Code: 73060
#
#
# 542312281523682 	 0.5774 	 797, 3379, 99203
# Senility without mention of psychosis
# Unspecified disorder of autonomic nervous system
# Unknown Code: 99203
#
#
# 542592281583084 	 0.4714 	 V8905, 2989, 99281
# Suspected cervical shortening not found
# Unspecified psychosis
# Unknown Code: 99281
#
#
# 542982281359230 	 0.4714 	 33510, 78701, 99215
# Spinal muscular atrophy, unspecified
# Nausea with vomiting
# Unknown Code: 99215
#
#
# 542272281043521 	 0.4714 	 71812, V571, 82274
# Loose body in joint, upper arm
# Care involving other physical therapy
# Unknown Code: 82274
#
#
# 542282281600648 	 0.4714 	 7807, 5992, 80053
# Unknown Code: 7807
# Urethral diverticulum
# Open fracture of vault of skull without mention of intracranial injury, with moderate [1-24 hours] loss of consciousness
#
#
# 542542281059474 	 0.5774 	 1160, V553, 96365
# Blastomycosis
# Attention to colostomy
# Unknown Code: 96365
#
#
# 542342281511305 	 0.5774 	 71681, 71533, 76942
# Other specified arthropathy, shoulder region
# Osteoarthrosis, localized, not specified whether primary or secondary, forearm
# Unknown Code: 76942
#
#
# 542802281401702 	 0.4714 	 0668, 4019, 6238
# Other specified arthropod-borne viral diseases
# Unspecified essential hypertension
# Other specified noninflammatory disorders of vagina
#
#
# 542572280942227 	 0.4714 	 5131, 71250, 93232
# Abscess of mediastinum
# Unknown Code: 71250
# Unknown Code: 93232
#
#
# 542342281341657 	 0.4714 	 3813, 38010, 07999
# Other and unspecified chronic nonsuppurative otitis media
# Infective otitis externa, unspecified
# Unspecified viral infection
#
#
# 542982280956359 	 0.4714 	 29643, 57510, 90853
# Bipolar I disorder, most recent episode (or current) manic, severe, without mention of psychotic behavior
# Cholecystitis, unspecified
# Unknown Code: 90853
#
#
# 542242281154612 	 0.4714 	 V616, V5867, 97802
# Illegitimacy or illegitimate pregnancy
# Long-term (current) use of insulin
# Unknown Code: 97802
#
#
# 542342281483400 	 0.4714 	 2190, 76830, 51741
# Benign neoplasm of cervix uteri
# Unknown Code: 76830
# Unknown Code: 51741
#
#
# 542462281507161 	 0.4714 	 9553, E914, 65205
# Injury to radial nerve
# Foreign body accidentally entering eye and adnexa
# Unknown Code: 65205
#
#
# 542422281037580 	 0.4714 	 V725, 6267, G0145
# Radiological examination, not elsewhere classified
# Postcoital bleeding
# Unknown Code: G0145
#
#
# 542892280957136 	 0.4714 	 70702, 94522, 11041
# Pressure ulcer, upper back
# Blisters, epidermal loss [second degree] of foot
# Unknown Code: 11041
#
#
# 542102281056047 	 0.4714 	 71635, 71597, 89051
# Climacteric arthritis, pelvic region and thigh
# Osteoarthrosis, unspecified whether generalized or localized, ankle and foot
# Unknown Code: 89051
#
#
# 542272281434338 	 0.4714 	 27789, V854, 99204
# Other specified disorders of metabolism
# Unknown Code: V854
# Unknown Code: 99204
#
#
# 542752281453586 	 0.5774 	 7268, 7260, 73620
# Other peripheral enthesopathies
# Adhesive capsulitis of shoulder
# Unspecified deformity of finger
#
#
# 542212281240686 	 0.5774 	 78058, 93926, 82950
# Sleep related movement disorder, unspecified
# Unknown Code: 93926
# Unknown Code: 82950
#
#
# 542662281161541 	 0.4714 	 72292, J7040, 74020
# Other and unspecified disc disorder, thoracic region
# Unknown Code: J7040
# Unknown Code: 74020
#
#
# 542382281255817 	 0.4714 	 05442, 72887, 36415
# Dendritic keratitis
# Muscle weakness (generalized)
# Unknown Code: 36415
#
#
# 542132281159785 	 0.4714 	 V616, 71941, 99204
# Illegitimacy or illegitimate pregnancy
# Pain in joint, shoulder region
# Unknown Code: 99204
#
#
# 542882280976260 	 0.4714 	 3149, 3003, V5869
# Unspecified hyperkinetic syndrome
# Obsessive-compulsive disorders
# Long-term (current) use of other medications
#
#
# 542892281334584 	 0.4714 	 34672, V8801, 70544
# Chronic migraine without aura, without mention of intractable migraine with status migrainosus
# Acquired absence of both cervix and uterus
# Unknown Code: 70544
#
#
# 542902281591917 	 0.4714 	 V2649, V7283, 6264
# Other procreative management, counseling and advice
# Other specified pre-operative examination
# Irregular menstrual cycle
#
#
# 542852281229338 	 0.4714 	 20812, 83896, A9502
# Chronic leukemia of unspecified cell type, in relapse
# Unknown Code: 83896
# Unknown Code: A9502
#
#
# 542842281337988 	 0.4714 	 38021, 38918, 43811
# Cholesteatoma of external ear
# Sensorineural hearing loss, bilateral
# Late effects of cerebrovascular disease, aphasia
#
#
# 542372281229604 	 0.4714 	 72630, 72761, 49390
# Enthesopathy of elbow, unspecified
# Complete rupture of rotator cuff
# Asthma,unspecified type, unspecified
#
#
# 542992281604434 	 0.4714 	 71128, 96365, G0008
# Arthropathy in Behcet's syndrome, other specified sites
# Unknown Code: 96365
# Unknown Code: G0008
#
#
# 542612280837714 	 0.4714 	 71978, V5419, 73110
# Unknown Code: 71978
# Aftercare for healing traumatic fracture of other bone
# Unknown Code: 73110
#
#
# 542802280923586 	 0.4714 	 57430, 99213, A9579
# Calculus of bile duct with acute cholecystitis, without mention of obstruction
# Unknown Code: 99213
# Unknown Code: A9579
#
#
# 542972280893378 	 0.4082 	 38031, 38921, 3899, 92550
# Hematoma of auricle or pinna
# Mixed hearing loss, unilateral
# Unspecified hearing loss
# Unknown Code: 92550
#
#
# 542162281533518 	 0.4714 	 9153, 73140, 12001
# Blister of finger(s), infected
# Unknown Code: 73140
# Unknown Code: 12001
#
#
# 542242281233520 	 0.4714 	 V6701, V4369, 73562
# Following surgery, follow-up vaginal pap smear
# Other joint replacement
# Unknown Code: 73562
#
#
# 542532281318687 	 0.4714 	 78704, 25042, 76700
# Bilious emesis
# Diabetes with renal manifestations, type II or unspecified type, uncontrolled
# Unknown Code: 76700
#
#
# 542532281530986 	 0.4714 	 38630, V4579, 92541
# Labyrinthitis, unspecified
# Other acquired absence of organ
# Unknown Code: 92541
#
#
# 542682281057904 	 0.4714 	 7042, 2141, 93971
# Abnormalities of the hair
# Lipoma of other skin and subcutaneous tissue
# Unknown Code: 93971
#
#
# 542762281387821 	 0.4714 	 82320, A0425, A0428, A0428
# Closed fracture of shaft of tibia alone
# Unknown Code: A0425
# Unknown Code: A0428
# Unknown Code: A0428
#
#
# 542542281092169 	 0.4714 	 3859, 90718, A0427
# Unspecified disorder of middle ear and mastoid
# Unknown Code: 90718
# Unknown Code: A0427
#
#
# 542652280952908 	 0.4714 	 V260, 99212, 96372
# Tuboplasty or vasoplasty after previous sterilization
# Unknown Code: 99212
# Unknown Code: 96372
#
#
# 542972281022382 	 0.4714 	 29621, 317, 90857
# Major depressive affective disorder, single episode, mild
# Mild mental retardation
# Unknown Code: 90857
#
#
# 542722281645399 	 0.4714 	 5755, 7906, 74181
# Fistula of gallbladder
# Other abnormal blood chemistry
# Unknown Code: 74181
#
#
# 542582280860877 	 0.4714 	 7848, 4730, 99212
# Hemorrhage from throat
# Chronic maxillary sinusitis
# Unknown Code: 99212
#
#
# 542822281486246 	 0.4714 	 9926, 71945, A0425
# Heat fatigue, transient
# Pain in joint, pelvic region and thigh
# Unknown Code: A0425
#
#
# 542722280980311 	 0.4714 	 72210, 71946, 90801
# Displacement of lumbar intervertebral disc without myelopathy
# Pain in joint, lower leg
# Unknown Code: 90801
#
#
# 542072281355471 	 0.4714 	 29635, 33394, G0410, G0410
# Major depressive affective disorder, recurrent episode, in partial or unspecified remission
# Restless legs syndrome (RLS)
# Unknown Code: G0410
# Unknown Code: G0410
#
#
# 542252281142689 	 0.4714 	 7825, 4779, 70360
# Cyanosis
# Allergic rhinitis, cause unspecified
# Unknown Code: 70360
#
#
# 542342281298890 	 0.5774 	 59800, E9289, 80050
# Urethral structure due to unspecified infection
# Unspecified accident
# Open fracture of vault of skull without mention of intracranial injury, unspecified state of consciousness
#
#
# 542842281132683 	 0.4714 	 72664, 72981, 95870
# Patellar tendinitis
# Swelling of limb
# Unknown Code: 95870
#
#
# 542872281252283 	 0.4714 	 1505, 77336, 99245
# Malignant neoplasm of lower third of esophagus
# Unknown Code: 77336
# Unknown Code: 99245
#
#
# 542682281621783 	 0.4714 	 2307, 7906, 99212
# Carcinoma in situ of other and unspecified parts of intestine
# Other abnormal blood chemistry
# Unknown Code: 99212
#
#
# 542712280990529 	 0.4714 	 73729, 72252, 72120
# Other lordosis (acquired)
# Degeneration of lumbar or lumbosacral intervertebral disc
# Unknown Code: 72120
#
#
# 542572281021203 	 0.4714 	 V187, 82565, 81001
# Family history of other genitourinary diseases
# Unknown Code: 82565
# Closed fracture of sternal end of clavicle
#
#
# 542292281438359 	 0.4714 	 59652, G0103, 86706
# Low bladder compliance
# Unknown Code: G0103
# Unknown Code: 86706
#
#
# 542692280974624 	 0.4714 	 36264, J2778, 52000
# Senile reticular degeneration
# Unknown Code: J2778
# Unknown Code: 52000
#
#
# 542782281597326 	 0.4714 	 2831, V066, 84481
# Unknown Code: 2831
# Need for prophylactic vaccination and inoculation against streptococcus pneumoniae [pneumococcus] and influenza
# Unknown Code: 84481
#
#
# 542792281469940 	 0.4714 	 2793, J1200, 84160
# Unspecified immunity deficiency
# Unknown Code: J1200
# Unknown Code: 84160
#
#
# 542152281045173 	 0.4082 	 V4363, 93924, 77082, 73650
# Wrist joint replacement
# Unknown Code: 93924
# Other apnea of newborn
# Unknown Code: 73650
#
#
# 542432280865557 	 0.5774 	 80709, 311, 80502
# Closed fracture of multiple ribs, unspecified
# Depressive disorder, not elsewhere classified
# Closed fracture of second cervical vertebra
#
#
# 542752281302872 	 0.4714 	 20087, A9552, 78815
# Other named variants of lymphosarcoma and reticulosarcoma, spleen
# Unknown Code: A9552
# Unknown Code: 78815
#
#
# 542512281092328 	 0.4714 	 72611, 42769, 93922
# Calcifying tendinitis of shoulder
# Other premature beats
# Unknown Code: 93922
#
#
# 542582281085049 	 0.4714 	 81251, 80197, 96372
# Open supracondylar fracture of humerus
# Unknown Code: 80197
# Unknown Code: 96372
#
#
# 542762281299706 	 0.4714 	 71993, 436, 73560
# Unspecified disorder of joint, forearm
# Acute, but ill-defined, cerebrovascular disease
# Unknown Code: 73560
#
#
# 542212281571891 	 0.4714 	 2840, 2384, V5864
# Unknown Code: 2840
# Polycythemia vera
# Long-term (current) use of non-steroidal anti-inflammatories (NSAID)
#
#
# 542952281129642 	 0.5774 	 36812, 60784, 70551
# Transient visual loss
# Impotence of organic origin
# Unknown Code: 70551
#
#
# 542332281558046 	 0.4714 	 28319, 5692, 82040
# Other non-autoimmune hemolytic anemias
# Stenosis of rectum and anus
# Unknown Code: 82040
#
#
# 542872281281972 	 0.5774 	 72887, 2392, L4210
# Muscle weakness (generalized)
# Neoplasm of unspecified nature of bone, soft tissue, and skin
# Unknown Code: L4210
#
#
# 542712280981188 	 0.4714 	 3892, 462, 70486
# Unknown Code: 3892
# Acute pharyngitis
# Unknown Code: 70486
#
#
# 542872281110374 	 0.4714 	 69270, J1030, 85730
# Unspecified dermatitis due to sun
# Unknown Code: J1030
# Unknown Code: 85730
#
#
# 542772281564276 	 0.4714 	 7915, 58181, 99000
# Glycosuria
# Nephrotic syndrome in diseases classified elsewhere
# Unknown Code: 99000
#
#
# 542272280912334 	 0.4714 	 29541, 9693, 90853
# Schizophreniform disorder, subchronic
# Poisoning by other antipsychotics, neuroleptics, and major tranquilizers
# Unknown Code: 90853
#
#
# 542512281392099 	 0.5774 	 20008, 20290, 57420
# Reticulosarcoma, lymph nodes of multiple sites
# Other and unspecified malignant neoplasms of lymphoid and histiocytic tissue, unspecified site, extranodal and solid organ sites
# Calculus of gallbladder without mention of cholecystitis, without mention of obstruction
#
#
# 542592281121827 	 0.4714 	 38842, 99307, 93225
# Hyperacusis
# Unknown Code: 99307
# Unknown Code: 93225
#
#
# 542582281107514 	 0.5774 	 1619, 31231, 74150
# Malignant neoplasm of larynx, unspecified
# Pathological gambling
# Unknown Code: 74150
#
#
# 542572281522611 	 0.4714 	 V715, 71101, A0428
# Observation following alleged rape or seduction
# Pyogenic arthritis, shoulder region
# Unknown Code: A0428
#
#
# 542692281221421 	 0.4714 	 46410, 7919, 76376
# Acute tracheitis without mention of obstruction
# Other nonspecific findings on examination of urine
# Unknown Code: 76376
#
#
# 542072281216990 	 0.4714 	 1161, V1301, 87070
# Paracoccidioidomycosis
# Personal history of urinary calculi
# Unknown Code: 87070
#
#
# 542282281155773 	 0.4714 	 71665, 71950, 99214
# Unspecified monoarthritis, pelvic region and thigh
# Stiffness of joint, not elsewhere classified, site unspecified
# Unknown Code: 99214
#
#
# 542462281103657 	 0.5774 	 71526, V5413, 72148
# Osteoarthrosis, localized, secondary, lower leg
# Aftercare for healing traumatic fracture of hip
# Unknown Code: 72148
#
#
# 542452280848786 	 0.4714 	 71814, 2749, 97004
# Loose body in joint, hand
# Gout, unspecified
# Unknown Code: 97004
#
#
# 542762280997210 	 0.4714 	 9213, 73060, 90703
# Contusion of eyeball
# Unknown Code: 73060
# Unknown Code: 90703
#
#
# 542482281229333 	 0.4714 	 29564, 3051, 85048
# Schizophrenic disorders, residual type, chronic with acute exacerbation
# Tobacco use disorder
# Unknown Code: 85048
#
#
# 542842281048332 	 0.4714 	 6190, 87491, 87205
# Urinary-genital tract fistula, female
# Unknown Code: 87491
# Unknown Code: 87205
#
#
# 542212281586997 	 0.4714 	 1535, 5990, 99202
# Malignant neoplasm of appendix vermiformis
# Urinary tract infection, site not specified
# Unknown Code: 99202
#
#
# 542972280890636 	 0.4714 	 05471, V1046, 36415
# Visceral herpes simplex
# Personal history of malignant neoplasm of prostate
# Unknown Code: 36415
#
#
# 542022281572859 	 0.5774 	 7215, 3561, 70491
# Kissing spine
# Peroneal muscular atrophy
# Unknown Code: 70491
#
#
# 542902281316626 	 0.4714 	 74682, 78609, 99211
# Cor triatriatum
# Other respiratory abnormalities
# Unknown Code: 99211
#
#
# 542752281326985 	 0.4714 	 V070, 76000, A9579
# Need for isolation
# Unknown Code: 76000
# Unknown Code: A9579
#
#
# 542902281626268 	 0.4714 	 8363, 8442, 97010
# Dislocation of patella, closed
# Sprain of cruciate ligament of knee
# Unknown Code: 97010
#
#
# 542912281004956 	 0.4714 	 4271, 24290, 93280
# Paroxysmal ventricular tachycardia
# Thyrotoxicosis without mention of goiter or other cause, and without mention of thyrotoxic crisis or storm
# Unknown Code: 93280
#
#
# 542832281214641 	 0.5774 	 V4583, 70543, G0206
# Breast implant removal status
# Unknown Code: 70543
# Unknown Code: G0206
#
#
# 542982281089728 	 0.4714 	 5561, J0135, 85025
# Ulcerative (chronic) ileocolitis
# Unknown Code: J0135
# Unknown Code: 85025
#
#
# 542642280881347 	 0.5774 	 V788, 7515, 82272
# Screening for other disorders of blood and blood-forming organs
# Other anomalies of intestine
# Unknown Code: 82272
#
#
# 542752281220551 	 0.4082 	 8975, 97004, 26418, 26418, J2175, J2175
# Traumatic amputation of leg(s) (complete) (partial), unilateral, level not specified, complicated
# Unknown Code: 97004
# Unknown Code: 26418
# Unknown Code: 26418
# Unknown Code: J2175
# Unknown Code: J2175
#
#
# 542622280965740 	 0.4714 	 1401, 7856, 99201
# Malignant neoplasm of lower lip, vermilion border
# Enlargement of lymph nodes
# Unknown Code: 99201
#
#
# 542492280917838 	 0.4714 	 V492, 72193, 96361
# Motor problems with limbs
# Unknown Code: 72193
# Unknown Code: 96361
#
#
# 542202281581484 	 0.4714 	 47870, 90761, 81015
# Unspecified disease of larynx
# Unknown Code: 90761
# Unknown Code: 81015
#
#
# 542482281341445 	 0.4714 	 V285, 7210, 73030
# Antenatal screening for isoimmunization
# Cervical spondylosis without myelopathy
# Periostitis, without mention of osteomyelitis, site unspecified
#
#
# 542762281582837 	 0.4714 	 V044, V4365, 82565
# Need for prophylactic vaccination and inoculation against yellow fever
# Knee joint replacement
# Unknown Code: 82565
#
#
# 542962280925926 	 0.4714 	 1408, 99283, 93325
# Malignant neoplasm of other sites of lip
# Unknown Code: 99283
# Unknown Code: 93325
#
#
# 542372281524137 	 0.4714 	 1740, G0204, 88271
# Malignant neoplasm of nipple and areola of female breast
# Unknown Code: G0204
# Unknown Code: 88271
#
#
# 542502281500943 	 0.5774 	 8942, E9204, 86927
# Multiple and unspecified open wound of lower limb, with tendon involvement
# Accidents caused by other hand tools and implements
# Unknown Code: 86927
#
#
# 542962281089859 	 0.4714 	 1732, 88331, 12032
# Other malignant neoplasm of skin of ear and external auditory canal
# Unknown Code: 88331
# Unknown Code: 12032
#
#
# 542842281071575 	 0.4082 	 8832, 78057, 7963, 36246
# Open wound of finger(s), with tendon involvement
# Unspecified sleep apnea
# Nonspecific low blood pressure reading
# Unknown Code: 36246
#
#
# 542572280934824 	 0.4714 	 V251, 84100, 93005
# Unknown Code: V251
# Unknown Code: 84100
# Unknown Code: 93005
#
#
# 542162281285306 	 0.4714 	 33391, 30000, 25000
# Stiff-man syndrome
# Anxiety state, unspecified
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled
#
#
# 542422281515634 	 0.4714 	 75241, 96366, 50200
# Embryonic cyst of cervix, vagina, and external female genitalia
# Unknown Code: 96366
# Unknown Code: 50200
#
#
# 542542281298042 	 0.4714 	 38916, 92557, 92504
# Sensorineural hearing loss, asymmetrical
# Unknown Code: 92557
# Unknown Code: 92504
#
#
# 542592281426705 	 0.4714 	 82330, V6700, E9293
# Open fracture of shaft of tibia alone
# Follow-up examination, following surgery, unspecified
# Late effects of accidental fall
#
#
# 542222281437303 	 0.4714 	 81101, V4501, 71941
# Closed fracture of acromial process of scapula
# Cardiac pacemaker in situ
# Pain in joint, shoulder region
#
#
# 542362280929211 	 0.4714 	 71897, 84550, 74150
# Unspecified derangement of joint, ankle and foot
# Unknown Code: 84550
# Unknown Code: 74150
#
#
# 542332280891162 	 0.4714 	 8406, 73090, G0101
# Supraspinatus (muscle) (tendon) sprain
# Unspecified infection of bone, site unspecified
# Unknown Code: G0101
#
#
# 542312281292250 	 0.4714 	 20952, V1259, 99211
# Benign carcinoid tumor of the cecum
# Personal history of other diseases of circulatory system
# Unknown Code: 99211
#
#
# 542912281159565 	 0.5774 	 71515, 97026, J7322
# Osteoarthrosis, localized, primary, pelvic region and thigh
# Unknown Code: 97026
# Unknown Code: J7322
#
#
# 542032281238929 	 0.5774 	 62929, 62212, 6266
# Other female genital mutilation status
# Moderate dysplasia of cervix
# Metrorrhagia
#
#
# 542522281378903 	 0.4714 	 243, 78006, A9560
# Congenital hypothyroidism
# Unknown Code: 78006
# Unknown Code: A9560
#
#
# 542542281132605 	 0.4714 	 20004, 70553, 82043
# Reticulosarcoma, lymph nodes of axilla and upper limb
# Unknown Code: 70553
# Unknown Code: 82043
#
#
# 542242281561787 	 0.4714 	 V8404, 87077, 85651
# Genetic susceptibility to malignant neoplasm of endometrium
# Unknown Code: 87077
# Unknown Code: 85651
#
#
# 542412281404098 	 0.4714 	 29603, 99791, 90801
# Bipolar I disorder, single manic episode, severe, without mention of psychotic behavior
# Complications affecting other specified body systems, not elsewhere classified, hypertension
# Unknown Code: 90801
#
#
# 542142280900701 	 0.4714 	 72931, 73560, 74160
# Hypertrophy of fat pad, knee
# Unknown Code: 73560
# Unknown Code: 74160
#
#
# 542902281607377 	 0.4714 	 80843, 27800, Q9965
# Multiple closed pelvic fractures with disruption of pelvic circle
# Obesity, unspecified
# Unknown Code: Q9965
#
#
# 542642281146877 	 0.4714 	 V438, 70553, 74160
# Unknown Code: V438
# Unknown Code: 70553
# Unknown Code: 74160
#
#
# 542952281430740 	 0.4714 	 29543, J1631, 90806
# Schizophreniform disorder, subchronic with acute exacerbation
# Unknown Code: J1631
# Unknown Code: 90806
#
#
# 542872281099776 	 0.4714 	 43842, 2949, 80069
# Late effects of cerebrovascular disease, monoplegia of lower limb affecting nondominant side
# Unspecified persistent mental disorders due to conditions classified elsewhere
# Open fracture of vault of skull with cerebral laceration and contusion, with concussion, unspecified
#
#
# 542452281392312 	 0.4714 	 7015, 25070, 11402
# Other abnormal granulation tissue
# Diabetes with peripheral circulatory disorders, type II or unspecified type, not stated as uncontrolled
# Unknown Code: 11402
#
#
# 542942281327807 	 0.4714 	 V561, 82570, A9562
# Fitting and adjustment of extracorporeal dialysis catheter
# Unknown Code: 82570
# Unknown Code: A9562
#
#
# 542632281150201 	 0.5774 	 V709, 99662, 94762
# Unspecified general medical examination
# Infection and inflammatory reaction due to other vascular device, implant, and graft
# Unknown Code: 94762
#
#
# 542962280984091 	 0.4714 	 69271, 2449, 81003
# Sunburn
# Unspecified acquired hypothyroidism
# Closed fracture of acromial end of clavicle
#
#
# 542792281050323 	 0.4714 	 6829, 10060, 87210
# Cellulitis and abscess of unspecified sites
# Unknown Code: 10060
# Open wound of external ear, unspecified site, complicated
#
#
# 542182281189658 	 0.4714 	 70700, 6961, 29580
# Pressure ulcer, unspecified site
# Other psoriasis
# Other specified types of schizophrenia, unspecified
#
#
# 542652281415278 	 0.4714 	 9465, 25000, A9270
# Deep necrosis of underlying tissues [deep third degree] with loss of a body part, of multiple specified sites
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled
# Unknown Code: A9270
#
#
# 542172281322018 	 0.4714 	 72883, Q1003, 70544
# Rupture of muscle, nontraumatic
# Unknown Code: Q1003
# Unknown Code: 70544
#
#
# 542672281162252 	 0.4714 	 1227, 99212, G0145
# Echinococcus multilocularis infection, unspecified
# Unknown Code: 99212
# Unknown Code: G0145
#
#
# 542912281489751 	 0.4714 	 44589, 43882, 93922
# Atheroembolism of other site
# Other late effects of cerebrovascular disease, dysphagia
# Unknown Code: 93922
#
#
# 542822281488152 	 0.5774 	 V725, V1329, 44022
# Radiological examination, not elsewhere classified
# Personal history of other genital system and obstetric disorders
# Atherosclerosis of native arteries of the extremities with rest pain
#
#
# 542132280993080 	 0.5774 	 29990, 31234, 31381
# Unspecified pervasive developmental disorder, current or active state
# Intermittent explosive disorder
# Oppositional defiant disorder
#
#
# 542792281249518 	 0.4714 	 6068, 99282, 90718
# Infertility due to extratesticular causes
# Unknown Code: 99282
# Unknown Code: 90718
#
#
# 542282281377027 	 0.4714 	 72703, 73382, 73140
# Trigger finger (acquired)
# Nonunion of fracture
# Unknown Code: 73140
#
#
# 542592281252387 	 0.4714 	 73309, 5779, V7612
# Other osteoporosis
# Unspecified disease of pancreas
# Other screening mammogram
#
#
# 542072281549727 	 0.4714 	 V177, V4365, 87070
# Family history of arthritis
# Knee joint replacement
# Unknown Code: 87070
#
#
# 542822281029470 	 0.4714 	 V500, 33394, 99214
# Elective hair transplant for purposes other than remedying health states
# Restless legs syndrome (RLS)
# Unknown Code: 99214
#
#
# 542262280940299 	 0.4714 	 37834, 3739, 99212
# Monofixation syndrome
# Unspecified inflammation of eyelid
# Unknown Code: 99212
#
#
# 542992281108512 	 0.4714 	 71126, 84450, 70487
# Arthropathy in Behcet's syndrome, lower leg
# Unknown Code: 84450
# Unknown Code: 70487
#
#
# 542392281341887 	 0.4714 	 73086, J7030, 86927
# Other infections involving bone in diseases classified elsewhere, lower leg
# Unknown Code: J7030
# Unknown Code: 86927
#
#
# 542282281514197 	 0.4714 	 88029, 2724, 11042
# Open wound of multiple sites of shoulder and upper arm, with tendon involvement
# Other and unspecified hyperlipidemia
# Unknown Code: 11042
#
#
# 542932281483078 	 0.4714 	 3588, V573, 70450
# Other specified myoneural disorders
# Care involving speech-language therapy
# Unknown Code: 70450
#
#
# 542622280876048 	 0.4714 	 V529, 43882, 92607
# Fitting and adjustment of unspecified prosthetic device
# Other late effects of cerebrovascular disease, dysphagia
# Unknown Code: 92607
#
#
# 542322280960385 	 0.4714 	 36651, 37160, 99214
# Soemmering's ring
# Keratoconus, unspecified
# Unknown Code: 99214
#
#
# 542112280844463 	 0.4714 	 V446, 86900, C9244
# Other artificial opening of urinary tract status
# Unknown Code: 86900
# Unknown Code: C9244
#
#
# 542812281274203 	 0.4714 	 494, 4439, 0174T
# Unknown Code: 494
# Peripheral vascular disease, unspecified
# Unknown Code: 0174T
#
#
# 542422281428296 	 0.4714 	 3561, 3004, 99282
# Peroneal muscular atrophy
# Dysthymic disorder
# Unknown Code: 99282
#
#
# 542572281178813 	 0.5774 	 95914, 52462, 81500
# Other injury of external genitals
# Temporomandibular joint disorders, arthralgia of temporomandibular joint
# Closed fracture of metacarpal bone(s), site unspecified
#
#
# 542492280838595 	 0.4714 	 61650, 78841, 87210
# Ulceration of vulva, unspecified
# Urinary frequency
# Open wound of external ear, unspecified site, complicated
#
#
# 542072281361402 	 0.4082 	 36210, 25052, 25051, 67210
# Background retinopathy, unspecified
# Diabetes with ophthalmic manifestations, type II or unspecified type, uncontrolled
# Diabetes with ophthalmic manifestations, type I [juvenile type], not stated as uncontrolled
# Unknown Code: 67210
#
#
# 542702281407482 	 0.4714 	 42820, 87324, 82951
# Systolic heart failure, unspecified
# Unknown Code: 87324
# Unknown Code: 82951
#
#
# 542882281335952 	 0.4714 	 29662, 2869, 71941
# Bipolar I disorder, most recent episode (or current) mixed, moderate
# Other and unspecified coagulation defects
# Pain in joint, shoulder region
#
#
# 542192280864701 	 0.4714 	 71823, 7295, 73060
# Pathological dislocation of joint, forearm
# Pain in limb
# Unknown Code: 73060
#
#
# 542162281388993 	 0.4714 	 36921, 25050, 92012
# Better eye: severe vision impairment; lesser eye; impairment not further specified
# Diabetes with ophthalmic manifestations, type II or unspecified type, not stated as uncontrolled
# Unknown Code: 92012
#
#
# 542822280875052 	 0.4714 	 42650, 51881, 93733
# Bundle branch block, unspecified
# Acute respiratory failure
# Unknown Code: 93733
#
#
# 542572281348031 	 0.5774 	 2144, 70211, A9579
# Lipoma of spermatic cord
# Inflamed seborrheic keratosis
# Unknown Code: A9579
#
#
# 542762280847392 	 0.4714 	 36913, 2724, 92012
# Better eye: severe vision impairment; lesser eye: near-total vision impairment
# Other and unspecified hyperlipidemia
# Unknown Code: 92012
#
#
# 542322281434746 	 0.4714 	 0738, 90761, 81001
# Ornithosis with unspecified complication
# Unknown Code: 90761
# Closed fracture of sternal end of clavicle
#
#
# 542772281148990 	 0.4714 	 5070, 3334, 2761
# Pneumonitis due to inhalation of food or vomitus
# Huntington's chorea
# Hyposmolality and/or hyponatremia
#
#
# 542082280982024 	 0.5774 	 59983, 75261, C1769
# Urethral instability
# Hypospadias
# Unknown Code: C1769
#
#
# 542402281071214 	 0.4714 	 570, 99213, A9581
# Acute and subacute necrosis of liver
# Unknown Code: 99213
# Unknown Code: A9581
#
#
# 542332281368088 	 0.4714 	 7235, A0998, 72170
# Torticollis, unspecified
# Unknown Code: A0998
# Unknown Code: 72170
#
#
# 542562281640588 	 0.4714 	 78603, 99202, 93971
# Apnea
# Unknown Code: 99202
# Unknown Code: 93971
#
#
# 542502281384648 	 0.5774 	 V723, 57421, G0202
# Unknown Code: V723
# Calculus of gallbladder without mention of cholecystitis, with obstruction
# Unknown Code: G0202
#
#
# 542092280994025 	 0.4714 	 V7241, C1879, 77052
# Pregnancy examination or test, negative result
# Unknown Code: C1879
# Unknown Code: 77052
#
#
# 542732281317396 	 0.4714 	 V4967, J0129, 29530
# Shoulder amputation status
# Unknown Code: J0129
# Paranoid type schizophrenia, unspecified
#
#
# 542212281012149 	 0.5774 	 52569, 311, D0120
# Other unsatisfactory restoration of existing tooth
# Depressive disorder, not elsewhere classified
# Unknown Code: D0120
#
#
# 542122281377075 	 0.4714 	 99686, V1046, A0425
# Complications of transplanted pancreas
# Personal history of malignant neoplasm of prostate
# Unknown Code: A0425
#
#
# 542402281427277 	 0.4714 	 9998, V103, 73630
# Unknown Code: 9998
# Personal history of malignant neoplasm of breast
# Unspecified acquired deformity of hip
#
#
# 542512281565953 	 0.4714 	 4918, 7942, 71270
# Other chronic bronchitis
# Nonspecific abnormal results of pulmonary function study
# Unknown Code: 71270
#
#
# 542032281381842 	 0.4714 	 1418, 71260, 77334
# Malignant neoplasm of other sites of tongue
# Unknown Code: 71260
# Unknown Code: 77334
#
#
# 542402281412674 	 0.5774 	 71481, 2459, 72052
# Rheumatoid lung
# Thyroiditis, unspecified
# Unknown Code: 72052
#
#
# 542132280989608 	 0.4714 	 V170, 93971, 85651
# Family history of psychiatric condition
# Unknown Code: 93971
# Unknown Code: 85651
#
#
# 542372281064771 	 0.4714 	 V1811, 79501, 87621
# Family history of multiple endocrine neoplasia [MEN] syndrome
# Papanicolaou smear of cervix with atypical squamous cells of undetermined significance (ASC-US)
# Unknown Code: 87621
#
#
# 542082281195034 	 0.4714 	 87359, 97602, 99212
# Open wound of other and multiple sites of face, complicated
# Unknown Code: 97602
# Unknown Code: 99212
#
#
# 542422281240288 	 0.5774 	 71596, 6805, V4989
# Osteoarthrosis, unspecified whether generalized or localized, lower leg
# Carbuncle and furuncle of buttock
# Other specified conditions influencing health status
#
#
# 542572281050245 	 0.4714 	 4330, V815, 93880
# Unknown Code: 4330
# Screening for nephropathy
# Unknown Code: 93880
#
#
# 542672280897387 	 0.4714 	 20294, 7931, 84155
# Other and unspecified malignant neoplasms of lymphoid and histiocytic tissue, lymph nodes of axilla and upper limb
# Nonspecific (abnormal) findings on radiological and other examination of lung field
# Unknown Code: 84155
#
#
# 542452281584039 	 0.4714 	 37732, 2724, 99212
# Retrobulbar neuritis (acute)
# Other and unspecified hyperlipidemia
# Unknown Code: 99212
#
#
# 542952280913878 	 0.5774 	 7042, 7821, 87140
# Abnormalities of the hair
# Rash and other nonspecific skin eruption
# Unknown Code: 87140
#
#
# 542932281098725 	 0.4714 	 V823, 4370, G0145
# Screening for congenital dislocation of hip
# Cerebral atherosclerosis
# Unknown Code: G0145
#
#
# 542952281188098 	 0.5774 	 78861, 51600, A0429
# Splitting of urinary stream
# Unknown Code: 51600
# Unknown Code: A0429
#
#
# 542132281293810 	 0.4714 	 7567, 99213, 80061
# Unknown Code: 7567
# Unknown Code: 99213
# Open fracture of vault of skull with cerebral laceration and contusion, with no loss of consciousness
#
#
# 542892281061854 	 0.4714 	 V174, 42760, 95811
# Unknown Code: V174
# Premature beats, unspecified
# Unknown Code: 95811
#
#
# 542722281498989 	 0.4714 	 V7650, V168, 73510
# Special screening for malignant neoplasms for intestine, unspecified
# Family history of other specified malignant neoplasm
# Unknown Code: 73510
#
#
# 542842280872366 	 0.4714 	 72470, 78903, 86923
# Unspecified disorder of coccyx
# Abdominal pain, right lower quadrant
# Unknown Code: 86923
#
#
# 542872281076429 	 0.4714 	 6102, 29633, 77051
# Fibroadenosis of breast
# Major depressive affective disorder, recurrent episode, severe, without mention of psychotic behavior
# Unknown Code: 77051
#
#
# 542032281034607 	 0.4714 	 3734, 36131, 92012
# Infective dermatitis of eyelid of types resulting in deformity
# Round hole of retina without detachment
# Unknown Code: 92012
#
#
# 542182281201095 	 0.4714 	 1718, 99215, 74150
# Malignant neoplasm of other specified sites of connective and other soft tissue
# Unknown Code: 99215
# Unknown Code: 74150
#
#
# 542542281581981 	 0.4714 	 59589, 5993, 99213
# Other specified types of cystitis
# Urethral caruncle
# Unknown Code: 99213
#
#
# 542552281551462 	 0.5774 	 0702, 56942, 86706
# Unknown Code: 0702
# Anal or rectal pain
# Unknown Code: 86706
#
#
# 542602280897696 	 0.4714 	 V1659, 82803, 94720
# Family history of malignant neoplasm of other
# Unknown Code: 82803
# Unknown Code: 94720
#
#
# 542952280961701 	 0.4714 	 V7211, 7823, 52332
# Encounter for hearing examination following failed hearing screening
# Edema
# Aggressive periodontitis, generalized
#
#
# 542412281639261 	 0.4714 	 4920, 61171, 94060
# Emphysematous bleb
# Mastodynia
# Unknown Code: 94060
#
#
# 542592280957837 	 0.4714 	 73320, 7392, 7393
# Cyst of bone (localized), unspecified
# Nonallopathic lesions, thoracic region
# Nonallopathic lesions, lumbar region
#
#
# 542792280885386 	 0.4714 	 7149, 27401, 96375
# Unspecified inflammatory polyarthropathy
# Acute gouty arthropathy
# Unknown Code: 96375
#
#
# 542042281461495 	 0.4714 	 7283, V144, 93970
# Other specific muscle disorders
# Personal history of allergy to anesthetic agent
# Unknown Code: 93970
#
#
# 542062281120674 	 0.4714 	 5998, 97112, 76830
# Unknown Code: 5998
# Unknown Code: 97112
# Unknown Code: 76830
#
#
# 542682281593321 	 0.4714 	 27952, A0425, A0427
# Chronic graft-versus-host disease
# Unknown Code: A0425
# Unknown Code: A0427
#
#
# 542082281489837 	 0.5774 	 30582, 4414, 90806
# Antidepressant type abuse, episodic
# Abdominal aneurysm without mention of rupture
# Unknown Code: 90806
#
#
# 542242281531318 	 0.4714 	 3481, 3510, A0425
# Anoxic brain damage
# Bell's palsy
# Unknown Code: A0425
#
#
# 542682281246049 	 0.4082 	 1118, V011, 1101, 87220
# Other specified dermatomycoses
# Contact with or exposure to tuberculosis
# Dermatophytosis of nail
# Unknown Code: 87220
#
#
# 542662281540145 	 0.4714 	 9663, A0425, A0427
# Poisoning by other and unspecified anticonvulsants
# Unknown Code: A0425
# Unknown Code: A0427
#
#
# 542552280931916 	 0.4714 	 6159, 87490, 87077
# Unspecified inflammatory disease of uterus
# Unknown Code: 87490
# Unknown Code: 87077
#
#
# 542242281271396 	 0.4714 	 4660, 78650, 7837
# Acute bronchitis
# Chest pain, unspecified
# Adult failure to thrive
#
#
# 542232281463221 	 0.4714 	 2722, V726, 49391
# Mixed hyperlipidemia
# Unknown Code: V726
# Asthma, unspecified type, with status asthmaticus
#
#
# 542882281610491 	 0.4714 	 2132, 4439, 99211
# Benign neoplasm of vertebral column, excluding sacrum and coccyx
# Peripheral vascular disease, unspecified
# Unknown Code: 99211
#
#
# 542022281332158 	 0.4714 	 5160, 70553, C1731
# Pulmonary alveolar proteinosis
# Unknown Code: 70553
# Unknown Code: C1731
#
#
# 542442281088473 	 0.4714 	 7851, P9603, J1652
# Palpitations
# Unknown Code: P9603
# Unknown Code: J1652
#
#
# 542432281582981 	 0.4714 	 38633, 38922, V7285
# Suppurative labyrinthitis
# Mixed hearing loss, bilateral
# Other specified examination
#
#
# 542752281441483 	 0.4714 	 5720, 99214, 96372
# Abscess of liver
# Unknown Code: 99214
# Unknown Code: 96372
#
#
# 542442281390803 	 0.4714 	 5739, 59970, 82140
# Unspecified disorder of liver
# Hematuria, unspecified
# Unknown Code: 82140
#
#
# 542202281409705 	 0.5774 	 36281, 92015, 93041
# Retinal hemorrhage
# Unknown Code: 92015
# Unknown Code: 93041
#
#
# 542842281341811 	 0.4714 	 6116, 59659, G0206
# Galactorrhea not associated with childbirth
# Other functional disorder of bladder
# Unknown Code: G0206
#
#
# 542922281114314 	 0.5774 	 34633, 7835, 99281
# Hemiplegic migraine, with intractable migraine, so stated, with status migrainosus
# Polydipsia
# Unknown Code: 99281
#
#
# 542592281048884 	 0.4714 	 37221, 37405, 99211, 99211
# Angular blepharoconjunctivitis
# Trichiasis of eyelid without entropion
# Unknown Code: 99211
# Unknown Code: 99211
#
#
# 542982281315621 	 0.4714 	 5128, 1991, 76604
# Other spontaneous pneumothorax
# Other malignant neoplasm without specification of site
# Unknown Code: 76604
#
#
# 542382281582261 	 0.4714 	 33720, 78607, 72070
# Reflex sympathetic dystrophy, unspecified
# Wheezing
# Unknown Code: 72070
#
#
# 542152280908605 	 0.4714 	 V417, V726, P9603
# Problems with sexual function
# Unknown Code: V726
# Unknown Code: P9603
#
#
# 542122281442165 	 0.4082 	 V491, V138, 43239, Q9958
# Mechanical problems with limbs
# Personal history of other specified diseases
# Unknown Code: 43239
# Unknown Code: Q9958
#
#
# 542842280991976 	 0.5774 	 3980, 75557, 82040
# Rheumatic myocarditis
# Macrodactylia (fingers)
# Unknown Code: 82040
#
#
# 542762281399036 	 0.4714 	 71696, A0425, A0427
# Arthropathy, unspecified, lower leg
# Unknown Code: A0425
# Unknown Code: A0427
#
#
# 542452281490336 	 0.5774 	 V5878, 78891, 72158
# Aftercare following surgery of the musculoskeletal system, NEC
# Functional urinary incontinence
# Unknown Code: 72158
#
#
# 542062281493429 	 0.4714 	 V802, V7381, P3000
# Screening for other eye conditions
# Special screening examination for Human papillomavirus (HPV)
# Unknown Code: P3000
#
#
# 542142281262252 	 0.4714 	 34641, 7930, 86850
# Menstrual migraine, with intractable migraine, so stated, without mention of status migrainosus
# Nonspecific (abnormal) findings on radiological and other examination of skull and head
# Unknown Code: 86850
#
#
# 542402281245036 	 0.4714 	 V5721, 72402, L1832
# Encounter for occupational therapy
# Spinal stenosis, lumbar region, without neurogenic claudication
# Unknown Code: L1832
#
#
# 542662281448788 	 0.4714 	 8842, 71275, 87040
# Multiple and unspecified open wound of upper limb, with tendon involvement
# Unknown Code: 71275
# Unknown Code: 87040
#
#
# 542292281483370 	 0.5774 	 74749, 93303, A9579
# Other anomalies of great veins
# Unknown Code: 93303
# Unknown Code: A9579
#
#
# 542872280848050 	 0.4714 	 V412, 92553, 84550
# Problems with hearing
# Unknown Code: 92553
# Unknown Code: 84550
#
#
# 542382281138142 	 0.4714 	 72671, 73510, 73500
# Achilles bursitis or tendinitis
# Unknown Code: 73510
# Unknown Code: 73500
#
#
# 542752281328949 	 0.5774 	 8761, 78039, 92309
# Open wound of back, complicated
# Other convulsions
# Contusion of multiple sites of shoulder and upper arm
#
#
# 542172281189636 	 0.4714 	 53241, 82272, 82570
# Chronic or unspecified duodenal ulcer with hemorrhage, with obstruction
# Unknown Code: 82272
# Unknown Code: 82570
#
#
# 542472280842714 	 0.4714 	 7104, 2769, 73302
# Polymyositis
# Electrolyte and fluid disorders not elsewhere classified
# Idiopathic osteoporosis
#
#
# 542992281055832 	 0.4714 	 08241, 80051, 87077
# Ehrlichiosis chafeensis [E. chafeensis]
# Open fracture of vault of skull without mention of intracranial injury, with no loss of consciousness
# Unknown Code: 87077
#
#
# 542912281635348 	 0.4714 	 V290, V8281, 99396
# Observation for suspected infectious condition
# Special screening for osteoporosis
# Unknown Code: 99396
#
#
# 542672281642774 	 0.4714 	 V017, 36415, A9270
# Unknown Code: V017
# Unknown Code: 36415
# Unknown Code: A9270
#
#
# 542912280915580 	 0.4714 	 5223, 4019, 99281
# Abnormal hard tissue formation in pulp
# Unspecified essential hypertension
# Unknown Code: 99281
#
#
# 542132281272840 	 0.4714 	 82341, C1788, 93005
# Torus fracture, fibula alone
# Unknown Code: C1788
# Unknown Code: 93005
#
#
# 542842280875248 	 0.4082 	 47879, 31575, 27530, 73200
# Other diseases of larynx, not elsewhere classified
# Unknown Code: 31575
# Unknown Code: 27530
# Unknown Code: 73200
#
#
# 542072280873202 	 0.5774 	 2322, 37200, 71260
# Carcinoma in situ of skin of ear and external auditory canal
# Acute conjunctivitis, unspecified
# Unknown Code: 71260
#
#
# 542692281216065 	 0.4714 	 82013, 87880, 96374
# Open fracture of base of neck of femur
# Unknown Code: 87880
# Unknown Code: 96374
#
#
# 542842281407969 	 0.4714 	 5930, 72192, 97001
# Nephroptosis
# Unknown Code: 72192
# Unknown Code: 97001
#
#
# 542682280861722 	 0.5774 	 6227, 78869, 88143
# Mucous polyp of cervix
# Other abnormality of urination
# Unknown Code: 88143
#
#
# 542252281420242 	 0.5774 	 V500, A9552, A0429
# Elective hair transplant for purposes other than remedying health states
# Unknown Code: A9552
# Unknown Code: A0429
#
#
# 542232280956864 	 0.4714 	 29606, J1580, Q9967
# Bipolar I disorder, single manic episode, in full remission
# Unknown Code: J1580
# Unknown Code: Q9967
#
#
# 542072281505911 	 0.4714 	 94525, E9248, 99213
# Blisters, epidermal loss [second degree] of knee
# Accident caused by other hot substance or object
# Unknown Code: 99213
#
#
# 542682281357144 	 0.4714 	 36457, 40300, 99285
# Degenerative changes of ciliary body
# Hypertensive chronic kidney disease, malignant, with chronic kidney disease stage I through stage IV, or unspecified
# Unknown Code: 99285
#
#
# 542102281403861 	 0.4714 	 7132, 97002, 73060
# Arthropathy associated with hematological disorders
# Unknown Code: 97002
# Unknown Code: 73060
#
#
# 542102281064200 	 0.4714 	 38400, 87070, 82728
# Acute myringitis, unspecified
# Unknown Code: 87070
# Unknown Code: 82728
#
#
# 542462281644858 	 0.4714 	 05882, 6989, 99202
# Human herpesvirus 7 infection
# Unspecified pruritic disorder
# Unknown Code: 99202
#
#
# 542272281407869 	 0.4714 	 7226, 72402, V672
# Degeneration of intervertebral disc, site unspecified
# Spinal stenosis, lumbar region, without neurogenic claudication
# Follow-up examination, following chemotherapy
#
#
# 542382281526936 	 0.4714 	 V499, V1254, 99214
# Unspecified problems with limbs and other problems
# Personal history of transient ischemic attack (TIA), and cerebral infarction without residual deficits
# Unknown Code: 99214
#
#
# 542852281590682 	 0.4714 	 71917, 4293, 99214
# Hemarthrosis, ankle and foot
# Cardiomegaly
# Unknown Code: 99214
#
#
# 542152281155276 	 0.5774 	 70900, V7263, 73140
# Dyschromia, unspecified
# Pre-procedural laboratory examination
# Unknown Code: 73140
#
#
# 542522280919118 	 0.4714 	 4431, 93293, 76856
# Thromboangiitis obliterans [Buerger's disease]
# Unknown Code: 93293
# Unknown Code: 76856
#
#
# 542202281349560 	 0.4714 	 36133, 83735, 84703
# Multiple defects of retina without detachment
# Unknown Code: 83735
# Unknown Code: 84703
#
#
# 542922280924962 	 0.4714 	 94110, 3051, 99211
# Erythema [first degree] of face and head, unspecified site
# Tobacco use disorder
# Unknown Code: 99211
#
#
# 542522281503588 	 0.4714 	 8461, 7241, 71101
# Sprain of sacroiliac ligament
# Pain in thoracic spine
# Pyogenic arthritis, shoulder region
#
#
# 542062280868349 	 0.4714 	 38802, 92604, 99212
# Transient ischemic deafness
# Unknown Code: 92604
# Unknown Code: 99212
#
#
# 542242281258595 	 0.4714 	 72811, V5883, 77080
# Progressive myositis ossificans
# Encounter for therapeutic drug monitoring
# Unknown Code: 77080
#
#
# 542452281138922 	 0.4714 	 V726, 38110, 2722
# Unknown Code: V726
# Chronic serous otitis media, simple or unspecified
# Mixed hyperlipidemia
#
#
# 542652280904075 	 0.4714 	 20934, 99205, 17311
# Merkel cell carcinoma of the lower limb
# Unknown Code: 99205
# Unknown Code: 17311
#
#
# 542342281518909 	 0.5774 	 79399, 99307, 87230
# Other nonspecific (abnormal) findings on radiological and other examinations of body structure
# Unknown Code: 99307
# Unknown Code: 87230
#
#
# 542972281448101 	 0.4714 	 8850, 70486, J0170
# Traumatic amputation of thumb (complete)(partial), without mention of complication
# Unknown Code: 70486
# Unknown Code: J0170
#
#
# 542352281333192 	 0.5774 	 72089, 78320, 64484
# Other inflammatory spondylopathies
# Unknown Code: 78320
# Unknown Code: 64484
#
#
# 542672281563693 	 0.4714 	 59652, 99211, J0882
# Low bladder compliance
# Unknown Code: 99211
# Unknown Code: J0882
#
#
# 542182280972537 	 0.5774 	 42761, 99334, 86361
# Supraventricular premature beats
# Unknown Code: 99334
# Unknown Code: 86361
#
#
# 542092281565243 	 0.4714 	 6022, 84402, 83880
# Atrophy of prostate
# Unknown Code: 84402
# Unknown Code: 83880
#
#
# 542782280987437 	 0.4714 	 34982, 99204, A9579
# Toxic encephalopathy
# Unknown Code: 99204
# Unknown Code: A9579
#
#
# 542562280903854 	 0.4714 	 7947, 2449, 82565
# Nonspecific abnormal results of function study of basal metabolism
# Unspecified acquired hypothyroidism
# Unknown Code: 82565
#
#
# 542912281189128 	 0.4714 	 36601, 33394, 73020
# Anterior subcapsular polar cataract
# Restless legs syndrome (RLS)
# Unspecified osteomyelitis, site unspecified
#
#
# 542822281184382 	 0.4714 	 71660, 7289, 73110
# Unspecified monoarthritis, site unspecified
# Unspecified disorder of muscle, ligament, and fascia
# Unknown Code: 73110
#
#
# 542472281222868 	 0.5774 	 9939, 71534, 72040
# Unspecified effect of air pressure
# Osteoarthrosis, localized, not specified whether primary or secondary, hand
# Unknown Code: 72040
#
#
# 542212281390746 	 0.4714 	 7144, 93556, 72192
# Chronic postrheumatic arthropathy
# Unknown Code: 93556
# Unknown Code: 72192
#
#
# 542622281528076 	 0.4714 	 V1501, 4770, 95117
# Allergy to peanuts
# Allergic rhinitis due to pollen
# Unknown Code: 95117
#
#
# 542522281486655 	 0.4714 	 78095, 49390, 7804
# Excessive crying of child, adolescent, or adult
# Asthma,unspecified type, unspecified
# Dizziness and giddiness
#
#
# 542112281205946 	 0.4714 	 8941, 87070, 97760
# Multiple and unspecified open wound of lower limb, complicated
# Unknown Code: 87070
# Unknown Code: 97760
#
#
# 542862280863644 	 0.4714 	 V252, 78830, 99212
# Sterilization
# Urinary incontinence, unspecified
# Unknown Code: 99212
#
#
# 542582281247121 	 0.4714 	 8245, 73560, A6209
# Bimalleolar fracture, open
# Unknown Code: 73560
# Unknown Code: A6209
#
#
# 542952280990018 	 0.4714 	 V112, 2722, 99213
# Personal history of neurosis
# Mixed hyperlipidemia
# Unknown Code: 99213
#
#
# 542992281601834 	 0.4714 	 9073, E8497, 99283
# Late effect of injury to nerve root(s), spinal plexus(es), and other nerves of trunk
# Accidents occurring in residential institution
# Unknown Code: 99283
#
#
# 542342281498424 	 0.4714 	 3534, 3869, 92506
# Lumbosacral root lesions, not elsewhere classified
# Unspecified vertiginous syndromes and labyrinthine disorders
# Unknown Code: 92506
#
#
# 542232281053983 	 0.4714 	 72252, 185, 95861
# Degeneration of lumbar or lumbosacral intervertebral disc
# Malignant neoplasm of prostate
# Unknown Code: 95861
#
#
# 542272280955010 	 0.4714 	 7902, 11730, 82306
# Unknown Code: 7902
# Unknown Code: 11730
# Unknown Code: 82306
#
#
# 542182281003871 	 0.4714 	 7135, 267, 97110
# Arthropathy associated with neurological disorders
# Ascorbic acid deficiency
# Unknown Code: 97110
#
#
# 542602281368348 	 0.4714 	 36609, 25000, 92025
# Other and combined forms of nonsenile cataract
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled
# Unknown Code: 92025
#
#
# 542192281016164 	 0.4714 	 38021, 38510, 92557
# Cholesteatoma of external ear
# Adhesive middle ear disease, unspecified as to involvement
# Unknown Code: 92557
#
#
# 542402281053863 	 0.4714 	 V2882, 73390, 78350
# Encounter for screening for risk of pre-term labor
# Disorder of bone and cartilage, unspecified
# Unknown Code: 78350
#
#
# 542582281633315 	 0.5774 	 V4569, 2246, 92015
# Other states following surgery of eye and adnexa
# Benign neoplasm of choroid
# Unknown Code: 92015
#
#
# 542372281579894 	 0.4714 	 78650, 390, 78465
# Chest pain, unspecified
# Rheumatic fever without mention of heart involvement
# Unknown Code: 78465
#
#
# 542212281241403 	 0.4714 	 0654, 99213, 92135
# Mosquito-borne hemorrhagic fever
# Unknown Code: 99213
# Unknown Code: 92135
#
#
# ...
# Closed fracture of shaft of clavicle
#
#
# 542932281566418 	 0.4714 	 V197, 43820, 95810
# Family history of consanguinity
# Late effects of cerebrovascular disease, hemiplegia affecting unspecified side
# Unknown Code: 95810
#
#
# 542432281432667 	 0.4714 	 71109, 73630, A9561
# Pyogenic arthritis, multiple sites
# Unspecified acquired deformity of hip
# Unknown Code: A9561
#
#
# 542692281336183 	 0.4082 	 34989, 725, 436, 92607
# Other specified disorders of nervous system
# Polymyalgia rheumatica
# Acute, but ill-defined, cerebrovascular disease
# Unknown Code: 92607
#
#
# 542592281564206 	 0.4714 	 51900, V1083, 87070
# Tracheostomy complication, unspecified
# Personal history of other malignant neoplasm of skin
# Unknown Code: 87070
#
#
# 542962281131108 	 0.5774 	 71526, 59582, 5303
# Osteoarthrosis, localized, secondary, lower leg
# Irradiation cystitis
# Stricture and stenosis of esophagus
#
#
# 542182281135903 	 0.5774 	 V495, 93924, A0426
# Other problems of limbs
# Unknown Code: 93924
# Unknown Code: A0426
#
#
# 542812280917676 	 0.5774 	 47829, 9093, 70542
# Other diseases of pharynx, not elsewhere classified
# Late effect of complications of surgical and medical care
# Unknown Code: 70542
#
#
# 542242281398445 	 0.4714 	 9552, 8821, 73110
# Injury to ulnar nerve
# Open wound of hand except finger(s) alone, complicated
# Unknown Code: 73110
#
#
# 542332281058177 	 0.4714 	 V5877, 5728, 77080
# Aftercare following surgery of the skin and subcutaneous tissue, NEC
# Other sequelae of chronic liver disease
# Unknown Code: 77080
#
#
# 542522281037894 	 0.4082 	 0072, V1082, 56982, 566
# Coccidiosis
# Personal history of malignant melanoma of skin
# Ulceration of intestine
# Abscess of anal and rectal regions
#
#
# 542482281539917 	 0.5774 	 78943, 93620, 26055
# Abdominal rigidity, right lower quadrant
# Unknown Code: 93620
# Unknown Code: 26055
#
#
# 542182281090011 	 0.4714 	 65173, 27800, 85027
# Multiple gestation following (elective) fetal reduction, antepartum condition or complication
# Obesity, unspecified
# Unknown Code: 85027
#
#
# 542092281139350 	 0.4714 	 20260, 77417, 77413
# Malignant mast cell tumors, unspecified site, extranodal and solid organ sites
# Unknown Code: 77417
# Unknown Code: 77413
#
#
# 542252280910102 	 0.4714 	 71526, 73027, 73630
# Osteoarthrosis, localized, secondary, lower leg
# Unspecified osteomyelitis, ankle and foot
# Unspecified acquired deformity of hip
#
#
# 542062281179894 	 0.5774 	 7863, V1201, E8199
# Unknown Code: 7863
# Personal history of tuberculosis
# Motor vehicle traffic accident of unspecified nature injuring unspecified person
#
#
# 542182281442002 	 0.4714 	 V130, 99306, 87088
# Unknown Code: V130
# Unknown Code: 99306
# Unknown Code: 87088
#
#
# 542052281381452 	 0.4714 	 36563, 37515, 99211
# Glaucoma associated with vascular disorders
# Tear film insufficiency, unspecified
# Unknown Code: 99211
#
#
# 542062281469998 	 0.4714 	 V8742, 80069, 82947
# Personal history of monoclonal drug therapy
# Open fracture of vault of skull with cerebral laceration and contusion, with concussion, unspecified
# Unknown Code: 82947
#
#
# 542662280873375 	 0.4714 	 37630, V431, 76512
# Exophthalmos, unspecified
# Lens replaced by other means
# Other preterm infants, 500-749 grams
#
#
# 542302281391985 	 0.4714 	 45350, 0414, 93971
# Chronic venous embolism and thrombosis of unspecified deep vessels of lower extremity
# Escherichia coli [E. coli] infection in conditions classified elsewhere and of unspecified site
# Unknown Code: 93971
#
#
# 542052280845365 	 0.4714 	 1603, V5881, 92507
# Malignant neoplasm of ethmoidal sinus
# Fitting and adjustment of vascular catheter
# Unknown Code: 92507
#
#
# 542812281408055 	 0.4714 	 9789, 80053, 81000
# Poisoning by mixed bacterial vaccines, except combinations with a pertussis component
# Open fracture of vault of skull without mention of intracranial injury, with moderate [1-24 hours] loss of consciousness
# Closed fracture of clavicle, unspecified part
#
#
# 542832281127933 	 0.5774 	 32729, 2899, 82140
# Other organic sleep apnea
# Unspecified diseases of blood and blood-forming organs
# Unknown Code: 82140
#
#
# 542382280956660 	 0.4714 	 72789, 7822, 73718
# Other disorders of synovium, tendon, and bursa
# Localized superficial swelling, mass, or lump
# Unknown Code: 73718
#
#
# 542432281261316 	 0.4714 	 79678, 7030, G0123
# Unsatisfactory anal cytology smear
# Ingrowing nail
# Unknown Code: G0123
#
#
# 542022281533984 	 0.4714 	 45181, V5413, 73510
# Phlebitis and thrombophlebitis of iliac vein
# Aftercare for healing traumatic fracture of hip
# Unknown Code: 73510
#
#
# 542522281614540 	 0.4714 	 V4585, 2246, P9604
# Insulin pump status
# Benign neoplasm of choroid
# Unknown Code: P9604
#
#
# 542602281636293 	 0.4714 	 71638, 2720, 72193
# Climacteric arthritis, other specified sites
# Pure hypercholesterolemia
# Unknown Code: 72193
#
#
# 542532281584966 	 0.5774 	 38530, 69274, 85347
# Cholesteatoma, unspecified
# Other chronic dermatitis due to solar radiation
# Unknown Code: 85347
#
#
# 542722281569150 	 0.4714 	 V1359, 93555, 97012
# Personal history of other musculoskeletal disorders
# Unknown Code: 93555
# Unknown Code: 97012
#
#
# 542632280900070 	 0.4714 	 1262, 87081, 81001
# Ancylostomiasis due to ancylostoma braziliense
# Unknown Code: 87081
# Closed fracture of sternal end of clavicle
#
#
# 542322281430431 	 0.4714 	 85186, E8889, 99201
# Other and unspecified cerebral laceration and contusion, without mention of open intracranial wound, with loss of consciousness of unspecified duration
# Unspecified fall
# Unknown Code: 99201
#
#
# 542222281134893 	 0.5774 	 20036, 42490, 77417
# Marginal zone lymphoma, intrapelvic lymph nodes
# Endocarditis, valve unspecified, unspecified cause
# Unknown Code: 77417
#
#
# 542122281639603 	 0.4714 	 42842, 486, 82785
# Chronic combined systolic and diastolic heart failure
# Pneumonia, organism unspecified
# Unknown Code: 82785
#
#
# 542022281232206 	 0.4714 	 24900, 2564, 41400
# Secondary diabetes mellitus without mention of complication, not stated as uncontrolled, or unspecified
# Polycystic ovaries
# Coronary atherosclerosis of unspecified type of vessel, native or graft
#
#
# 542612280837686 	 0.5774 	 29651, 3591, 99307
# Bipolar I disorder, most recent episode (or current) depressed, mild
# Hereditary progressive muscular dystrophy
# Unknown Code: 99307
#
#
# 542302281534101 	 0.4714 	 E9585, 78650, G0431
# Suicide and self-inflicted injury by crashing of motor vehicle
# Chest pain, unspecified
# Unknown Code: G0431
#
#
# 542312281385130 	 0.5774 	 71287, 73110, 87476
# Other specified crystal arthropathies, ankle and foot
# Unknown Code: 73110
# Unknown Code: 87476
#
#
# 542702281290235 	 0.4714 	 25631, 58100, 77031
# Premature menopause
# Unknown Code: 58100
# Unknown Code: 77031
#
#
# 542592281265559 	 0.5774 	 0210, 97110, 88274
# Ulceroglandular tularemia
# Unknown Code: 97110
# Unknown Code: 88274
#
#
# 542622281612555 	 0.4714 	 V4977, 8407, 73510
# Hip amputation status
# Superior glenoid labrum lesion
# Unknown Code: 73510
#
#
# 542622281364256 	 0.4714 	 V012, 90746, 90471
# Contact with or exposure to poliomyelitis
# Unknown Code: 90746
# Unknown Code: 90471
#
#
# 542972281557337 	 0.5774 	 5203, 3089, 20190
# Mottled teeth
# Unspecified acute reaction to stress
# Hodgkin's disease, unspecified type, unspecified site, extranodal and solid organ sites
#
#
# 542552281607033 	 0.4714 	 29625, 3013, 90806
# Major depressive affective disorder, single episode, in partial or unspecified remission
# Explosive personality disorder
# Unknown Code: 90806
#
#
# 542382280981609 	 0.5774 	 29656, 3019, 30393
# Bipolar I disorder, most recent episode (or current) depressed, in full remission
# Unspecified personality disorder
# Other and unspecified alcohol dependence, in remission
#
#
# 542952281312302 	 0.4714 	 V666, 71590, 11041
# Convalescence following combined treatment
# Osteoarthrosis, unspecified whether generalized or localized, site unspecified
# Unknown Code: 11041
#
#
# 542432281580474 	 0.4714 	 0748, 93556, 84443
# Other specified diseases due to Coxsackie virus
# Unknown Code: 93556
# Unknown Code: 84443
#
#
# 542342280918103 	 0.4714 	 5641, 90732, 36821
# Irritable bowel syndrome
# Unknown Code: 90732
# Unknown Code: 36821
#
#
# 542252281506126 	 0.5774 	 6850, 92526, 87015
# Pilonidal cyst with abscess
# Unknown Code: 92526
# Unknown Code: 87015
#
#
# 542282281176103 	 0.4714 	 3010, 90806, 90853
# Paranoid personality disorder
# Unknown Code: 90806
# Unknown Code: 90853
#
#
# 542532281230158 	 0.5774 	 V771, V242, 73080
# Screening for diabetes mellitus
# Routine postpartum follow-up
# Other infections involving bone in diseases classified elsewhere, site unspecified
#
#
# 542022280849238 	 0.5774 	 0086, 82710, A0427
# Unknown Code: 0086
# Unknown Code: 82710
# Unknown Code: A0427
#
#
# 542052280977074 	 0.4714 	 43842, 2639, 7140
# Late effects of cerebrovascular disease, monoplegia of lower limb affecting nondominant side
# Unspecified protein-calorie malnutrition
# Rheumatoid arthritis
#
#
# 542712281600860 	 0.4714 	 35981, 7291, 99204
# Critical illness myopathy
# Myalgia and myositis, unspecified
# Unknown Code: 99204
#
#
# 542032281433430 	 0.4714 	 33822, G0332, 85007
# Chronic post-thoracotomy pain
# Unknown Code: G0332
# Unknown Code: 85007
#
#
# 542252281608944 	 0.4714 	 1883, 73721, 88368
# Malignant neoplasm of anterior wall of urinary bladder
# Lordosis, postlaminectomy
# Unknown Code: 88368
#
#
# 542492281419173 	 0.4714 	 44029, 5929, 74185
# Other atherosclerosis of native arteries of the extremities
# Urinary calculus, unspecified
# Unknown Code: 74185
#
#
# 542762281554181 	 0.4714 	 V6540, 25060, 82040
# Counseling NOS
# Diabetes with neurological manifestations, type II or unspecified type, not stated as uncontrolled
# Unknown Code: 82040
#
#
# 542692281466834 	 0.4714 	 47874, 4784, 82550
# Stenosis of larynx
# Polyp of vocal cord or larynx
# Unknown Code: 82550
#
#
# 542972280914598 	 0.4714 	 V125, 2948, 74175
# Unknown Code: V125
# Other persistent mental disorders due to conditions classified elsewhere
# Unknown Code: 74175
#
#
# 542172281313354 	 0.4082 	 3380, 4400, G0379, 77790
# Central pain syndrome
# Atherosclerosis of aorta
# Unknown Code: G0379
# Unknown Code: 77790
#
#
# 542572281457226 	 0.4714 	 72470, 61610, 86200
# Unspecified disorder of coccyx
# Vaginitis and vulvovaginitis, unspecified
# Unknown Code: 86200
#
#
# 542352281067711 	 0.4714 	 684, 73620, 81003
# Impetigo
# Unspecified deformity of finger
# Closed fracture of acromial end of clavicle
#
#
# 542172281069539 	 0.5774 	 9139, 85221, 93017
# Other and unspecified superficial injury of elbow, forearm, and wrist, infected
# Subdural hemorrhage following injury without mention of open intracranial wound, with no loss of consciousness
# Unknown Code: 93017
#
#
# 542912281625523 	 0.4714 	 29635, 30422, G0410
# Major depressive affective disorder, recurrent episode, in partial or unspecified remission
# Cocaine dependence, episodic
# Unknown Code: G0410
#
#
# 542082281638318 	 0.4714 	 5798, 36201, 83516
# Other specified intestinal malabsorption
# Background diabetic retinopathy
# Unknown Code: 83516
#
#
# 542032281553979 	 0.4714 	 5793, 5609, 11041
# Other and unspecified postsurgical nonabsorption
# Unspecified intestinal obstruction
# Unknown Code: 11041
#
#
# 542912281129660 	 0.4714 	 65121, 82570, 84443
# Quadruplet pregnancy, delivered, with or without mention of antepartum condition
# Unknown Code: 82570
# Unknown Code: 84443
#
#
# 542472281392258 	 0.4714 	 1740, 19881, 71250
# Malignant neoplasm of nipple and areola of female breast
# Secondary malignant neoplasm of breast
# Unknown Code: 71250
#
#
# 542892280906459 	 0.4714 	 V7381, 7149, 90658
# Special screening examination for Human papillomavirus (HPV)
# Unspecified inflammatory polyarthropathy
# Unknown Code: 90658
#
#
# 542232280987128 	 0.4714 	 4732, 7840, 31237
# Chronic ethmoidal sinusitis
# Headache
# Unknown Code: 31237
#
#
# 542552281074155 	 0.4714 	 34989, C1876, 90765
# Other specified disorders of nervous system
# Unknown Code: C1876
# Unknown Code: 90765
#
#
# 542692280898754 	 0.4714 	 V606, 496, G0108
# Person living in residential institution
# Chronic airway obstruction, not elsewhere classified
# Unknown Code: G0108
#
#
# 542122281165737 	 0.4714 	 V277, 80101, 87086
# Outcome of delivery, other multiple birth, all stillborn
# Closed fracture of base of skull without mention of intra cranial injury, with no loss of consciousness
# Unknown Code: 87086
#
#
# 542592281039670 	 0.4714 	 V276, 99212, 81001
# Outcome of delivery, other multiple birth, some liveborn
# Unknown Code: 99212
# Closed fracture of sternal end of clavicle
#
#
# 542302281308330 	 0.4714 	 V1789, 95811, 11100
# Family history, Other musculoskeletal diseases
# Unknown Code: 95811
# Unknown Code: 11100
#
#
# 542412281495481 	 0.4714 	 3102, 4011, 2980
# Postconcussion syndrome
# Benign essential hypertension
# Depressive type psychosis
#
#
# 542772281543091 	 0.4714 	 3102, 71945, 436
# Postconcussion syndrome
# Pain in joint, pelvic region and thigh
# Acute, but ill-defined, cerebrovascular disease
#
#
# 542042281414673 	 0.4714 	 0410, 99214, 85610
# Unknown Code: 0410
# Unknown Code: 99214
# Unknown Code: 85610
#
#
# 542912281522662 	 0.4714 	 99560, 2382, 99283
# Anaphylactic shock due to unspecified food
# Neoplasm of uncertain behavior of skin
# Unknown Code: 99283
#
#
# 542512281173384 	 0.4714 	 7012, 6110, 99211
# Acquired acanthosis nigricans
# Inflammatory disease of breast
# Unknown Code: 99211
#
#
# 542852281390472 	 0.4714 	 V7689, 74000, 84450
# Special screening for other malignant neoplasms
# Unknown Code: 74000
# Unknown Code: 84450
#
#
# 542202281128467 	 0.4714 	 2892, 97110, 84480
# Nonspecific mesenteric lymphadenitis
# Unknown Code: 97110
# Unknown Code: 84480
#
#
# 542032280923840 	 0.4714 	 V6400, 99215, 71260
# Vaccination not carried out, unspecified reason
# Unknown Code: 99215
# Unknown Code: 71260
#
#
# 542142281589136 	 0.4714 	 57420, J7030, A0435
# Calculus of gallbladder without mention of cholecystitis, without mention of obstruction
# Unknown Code: J7030
# Unknown Code: A0435
#
#
# 542852280970175 	 0.5774 	 36520, 67210, 92136
# Primary angle-closure glaucoma, unspecified
# Unknown Code: 67210
# Unknown Code: 92136
#
#
# 542372281154673 	 0.4714 	 78945, 70700, 74020
# Abdominal rigidity, periumbilic
# Pressure ulcer, unspecified site
# Unknown Code: 74020
#
#
# 542072281321383 	 0.4714 	 4410, 72193, 70553
# Unknown Code: 4410
# Unknown Code: 72193
# Unknown Code: 70553
#
#
# 542102281455014 	 0.4714 	 V5882, 40391, 83874
# Fitting and adjustment of nonvascular catheter, NEC
# Hypertensive chronic kidney disease, unspecified, with chronic kidney disease stage V or end stage renal disease
# Unknown Code: 83874
#
#
# 542192281213241 	 0.4714 	 37020, V4578, 99283
# Superficial keratitis, unspecified
# Acquired absence of organ, eye
# Unknown Code: 99283
#
#
# 542212281603446 	 0.4714 	 9943, G0431, A0427
# Effects of thirst
# Unknown Code: G0431
# Unknown Code: A0427
#
#
# 542422280859410 	 0.4714 	 V418, 84152, 85027
# Other problems with special functions
# Unknown Code: 84152
# Unknown Code: 85027
#
#
# 542902280995328 	 0.4714 	 1339, 82565, 99284
# Acariasis, unspecified
# Unknown Code: 82565
# Unknown Code: 99284
#
#
# 542682281347709 	 0.4714 	 36112, V5866, 93306
# Bullous retinoschisis
# Long-term (current) use of aspirin
# Unknown Code: 93306
#
#
# 542742281406932 	 0.4714 	 2329, 71536, V7283
# Carcinoma in situ of skin, site unspecified
# Osteoarthrosis, localized, not specified whether primary or secondary, lower leg
# Other specified pre-operative examination
#
#
# 542162280847683 	 0.4714 	 53021, 99307, 82378
# Ulcer of esophagus with bleeding
# Unknown Code: 99307
# Unknown Code: 82378
#
#
# 542942281602057 	 0.4714 	 4263, V1011, 93293
# Other left bundle branch block
# Personal history of malignant neoplasm of bronchus and lung
# Unknown Code: 93293
#
#
# 542612280928640 	 0.4082 	 4760, V142, 9953, 31579
# Chronic laryngitis
# Personal history of allergy to sulfonamides
# Allergy, unspecified, not elsewhere classified
# Unknown Code: 31579
#
#
# 542192281049765 	 0.4714 	 2271, A9505, 90765
# Benign neoplasm of parathyroid gland
# Unknown Code: A9505
# Unknown Code: 90765
#
#
# 542802281413402 	 0.4714 	 05313, 25000, 496
# Postherpetic polyneuropathy
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled
# Chronic airway obstruction, not elsewhere classified
#
#
# 542212280861908 	 0.4714 	 78704, 25050, 78264
# Bilious emesis
# Diabetes with ophthalmic manifestations, type II or unspecified type, not stated as uncontrolled
# Unknown Code: 78264
#
#
# 542942280878799 	 0.4714 	 42741, 93282, 71260
# Ventricular fibrillation
# Unknown Code: 93282
# Unknown Code: 71260

# %% [markdown]
# some examples of groups with manual lookup
#
# Radiation oncology treatment delivery
# Moderate hypoxic-ischemic encephalopathy
# Kidney stone analysis with stone imaging
#
# Unspecified polyarthropathy or polyarthritis, other specified sites
# Closed Colles' fracture
# Nerve Conduction Studies

# %% [markdown]
# Unclear how useful this model is.
#
# unfortunately(?) most of them seem fairly reasonable.
#
# probably need more data to ensure get some erroneous ones.
