# %% [markdown]
# # DS-SF-30 | Codealong 05: k-Nearest Neighbors

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import preprocessing, neighbors, grid_search, cross_validation

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-05-iris.csv'))

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# SepalLength    float64
# SepalWidth     float64
# PetalLength    float64
# PetalWidth     float64
# Species         object
# dtype: object

# %%
df.plot(kind='scatter', x='SepalWidth', y='PetalLength')

# %%
for c in df.loc[:, df.dtypes == 'float64']:
    for r in df.loc[:, df.dtypes == 'float64']:
        if r != c and r != 'Species' and c != 'Species':
            df.plot(kind='scatter', x=c, y=r)

# %%
from pandas.tools.plotting import scatter_matrix

#scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')

pd.tools.plotting.scatter_matrix(df.select_dtypes(include=[np.float]),
                                diagonal = 'kde', s = 75, c = color, figsize = (12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121a55dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121b05c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123951350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10669e390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10671f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9b72d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca37410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1239a7390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123a155d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a97550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123c2d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123cade90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123ab1c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123d44250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123dc61d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e28590>]], dtype=object)

# %% [markdown]
# ## Part A - Activity | Iris dataset: Exploratory Data Analysis

# %%
color = df.Species.map({'Setosa': 'red', 'Versicolor': 'green', 'Virginica': 'blue'})

# %%
color.describe()
# Out:
# count     150
# unique      3
# top       red
# freq       50
# Name: Species, dtype: object

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# ## Part B - Hand-coded classifier

# %%
c = df.Species

# %%
def my_first_classifier(row):
    if row.PetalLength < 2.5:
        return 'Setosa'
    if row.PetalWidth < 0.8:
        return 'Setosa'
    if (row.SepalLength / row.SepalWidth) < 0.6:
        return 'Setosa'
    if row.PetalLength > 5.2: 
        return 'Virginica'
    if row.PetalWidth > 1.7:
        return 'Virginica'
    if row.SepalLength > 7.1:
        return 'Virginica'
    else:
        return 'Versicolor'

# %%
c_hat = df.apply(my_first_classifier, axis = 1)

c_hat
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# dtype: object

# %%
c_hat[lambda r: r == 'Setosa'].count()
# Out:
# 50

# %%
c_hat[lambda r: r == 'Virginica'].count()
# Out:
# 48

# %%
c_hat != c
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# dtype: bool

# %%
(c_hat != c).sum()
# Out:
# 4

# %%
pd.crosstab(c_hat, c)
# Out:
# Species     Setosa  Versicolor  Virginica
# row_0
# Setosa          50           0          0
# Versicolor       0          49          3
# Virginica        0           1         47

# %% [markdown]
# ## Part C - Classification metrics

# %% [markdown]
# ### Accuracy

# %%
# TODO
(c_hat == c).mean()
# Out:
# 0.97333333333333338

# %% [markdown]
# ### Misclassification rate

# %%
# TODO
(c_hat != c).mean()
# Out:
# 0.026666666666666668

# %% [markdown]
# ## Part D - k-Nearest Neighbors (k-NN)

# %% [markdown]
# ### Feature matrix and response vector

# %%
X = df[ ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'] ]

scaler = preprocessing.MinMaxScaler().fit(X)

X = scaler.transform(X)

# %%
X

# %%
c = df.Species

# %%
c

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = 1).\
    fit(X, c)

# %% [markdown]
# You can measure the precision of your prediction with `.score()`

# %%
model.score(X, c)

# %%
c_hat = model.predict(X)

# %%
(c_hat == c).mean()

# %%
pd.crosstab(c, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

# %% [markdown]
# ### Train/test sets

# %% [markdown]
# 50% of the dataset to train the model; the rest to test the model

# %%
train_df = df.sample(frac = .5, random_state = 0).sort_index()

# %%
train_df

# %%
test_df = df.drop(train_df.index)

# %% [markdown]
# ### Feature matrix `train_X` and response vector `train_c`

# %%
train_X = train_df[ ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'] ]

scaler = preprocessing.MinMaxScaler().fit(train_X)
train_X = scaler.transform(train_X)

train_c = train_df.Species

# %% [markdown]
# ### Feature matrix `test_X` and response vector `test_c`

# %%
# TODO

# %%
k_cv = 5 # 5-fold CV
k_nn = range(1, train_df.shape[0] * (k_cv - 1) / k_cv) # k-NN

gs = grid_search.GridSearchCV(
    estimator = neighbors.KNeighborsClassifier(),
    param_grid = {'n_neighbors': k_nn, 'weights': ['uniform', 'distance']},
    cv = cross_validation.KFold(train_df.shape[0], n_folds = k_cv)
)

gs.fit(train_X, train_c)

# %%
gs.grid_scores_

# %%
gs.best_score_

# %%
gs.best_params_

# %%
gs.best_estimator_

# %%
gs.score(train_X, train_c)

# %%
gs.score(test_X, test_c)

# %% [markdown]
# ## Final model

# %%
# TODO
